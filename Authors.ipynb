# %%
import pandas as pd
import numpy as np
import string
import re
import requests
import time
import csv
import json

from SPARQLWrapper import SPARQLWrapper, JSON, XML
from bs4 import BeautifulSoup

# %% [markdown]
# ### Get politifact info

# %%
file = 'Data/c4.csv'
df_claims = pd.read_csv(file,sep=",")
df_claims = df_claims.loc[(df_claims['organization'] != 'snopes')]

df_claims.head()
# Out:
#                                                   id  \
# 0  http://data.gesis.org/claimskg/creative_work/9...
# 1  http://data.gesis.org/claimskg/creative_work/e...
# 2  http://data.gesis.org/claimskg/creative_work/0...
# 3  http://data.gesis.org/claimskg/creative_work/f...
# 4  http://data.gesis.org/claimskg/creative_work/c...
#
#                                                 text              author  \
# 0  California’s Prop 55 'prevents $4 billion in n...           Yes on 55
# 1  Says an election clerk in Green Bay refused to...  Our Democracy 2020
# 2  Says state schools superintendent candidate Do...   One Wisconsin Now
# 3  'The Walton family, which owns Wal-Mart, contr...   One Wisconsin Now
# 4  In his first meeting with University of Wiscon...   One Wisconsin Now
#
#          date                                           keywords organization  \
# 0  03/26/2055                           education,state finances   politifact
# 1  03/26/2020  bipartisanship,city government,education,elect...   politifact
# 2  12/03/2019  corporations,education,small business,state bu...   politifact
# 3  11/27/2019           corporations,economy,income,labor,wealth   politifact
# 4  11/09/2019                             education,state budget   politifact
#
#     rating
# 0  MIXTURE
# 1  MIXTURE
# 2  MIXTURE
# 3     TRUE
# 4    FALSE

# %%
authors = df_claims["author"].unique()
print(len(authors))
# Out:
# 2076

# %%
links = list()
translator = str.maketrans('', '', string.punctuation)

for author in authors:
    if type(author) is str:
        link = author.translate(translator).lower()
        link = re.sub(" on "," ",link)
        link = re.sub(" of "," ",link)
        link = re.sub(" for "," ",link)
        link = re.sub(" a "," ",link)
        link = re.sub(" the "," ",link)
        if link[0:4] == 'for ':
            link = link[4:]
        if link[0:4] == 'the ':
            link = link[4:]
        link = link.strip()
        link = re.sub(" ","-",link)
        links.append(link)

# %%
def get_description(suffix):
    url = 'https://www.politifact.com/personalities/' + suffix 
    req = requests.get(url)
    if req.status_code == 200:
        html = req.text
        soup = BeautifulSoup(html, "lxml")
        description = soup.find('div', {'class' : 'scorecard__bio-text'})
        description = description.get_text(separator=' ')
        lines = (line.strip() for line in description.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        description = ' '.join(chunk for chunk in chunks if chunk)
        title = soup.find('h3', {'class' : 'scorecard__title'})
        title = title.get_text(separator=' ')
        lines = (line.strip() for line in title.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        title = ' '.join(chunk for chunk in chunks if chunk)
        p = re.compile("Our .* feeds")
        found = p.search(title)
        if found is not None:
            title = ''
        return [title,description]
    else:
        return None

# %%
authors_dict = {key:None for key in authors}

# %%
for i in range(len(links)):
    description = get_description(links[i])
    if description is not None:
        authors_dict[authors[i]] = description
    time.sleep(0.3)

# %%
#SAVE AS CSV
rows = list()
header = ["author","title","description"]
rows.append(header)

for key,value in authors_dict.items():
    if value is not None:
        row = [key,value[0],value[1]]
    else:
        row = [key,'','']
    rows.append(row)

with open('Data/authors.csv','w',newline='',encoding="utf-8") as writeFile:
    writer = csv.writer(writeFile,delimiter=',')
    writer.writerows(rows)
    writeFile.close()

# %% [markdown]
# ### Get wikipedia info

# %%
file = 'Data/authors.csv'
df_authors = pd.read_csv(file,sep=",")

df_authors.head()
# Out:
#                author                         title  \
# 0           Yes on 55  Organization from California
# 1  Our Democracy 2020                           NaN
# 2   One Wisconsin Now   Organization from Wisconsin
# 3  Secure America Now                           NaN
# 4        Vote NO on 8             None from Florida
#
#                                          description
# 0  The Yes on 55 campaign supports Proposition 55...
# 1  Our Democracy 2020 is a Madison-based coalitio...
# 2  One Wisconsin Now is a liberal advocacy group ...
# 3  Secure America Now is an independent, non-prof...
# 4  The Vote NO on 8 group is urging Florida resid...

# %%
file = 'Data/output_full_17072019.csv'
df_new = pd.read_csv(file,sep=",")
df_new.head()
# Out:
# c:\users\leonardo.moros\env\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  claimReview_author claimReview_author_name  \
# 0           0                 NaN           factcheck_aap
# 1           1                 NaN           factcheck_aap
# 2           2                 NaN           factcheck_aap
# 3           3                 NaN           factcheck_aap
# 4           4                 NaN           factcheck_aap
#
#    claimReview_author_url                          claimReview_claimReviewed  \
# 0                     NaN  120,000 Tasmanians - a quarter of our populati...
# 1                     NaN  Over the census period numbers [of homeless pe...
# 2                     NaN  Since 2014 approximately $1.6 billion in healt...
# 3                     NaN  We’ve still got 90 per cent of the state in so...
# 4                     NaN  It has been a significant, unusual and sustain...
#
#   claimReview_datePublished claimReview_source  \
# 0                2019-07-08      factcheck_aap
# 1                2019-07-09      factcheck_aap
# 2                2019-07-03      factcheck_aap
# 3                2019-07-01      factcheck_aap
# 4                2019-06-21      factcheck_aap
#
#                                      claimReview_url  \
# 0  https://factcheck.aap.com.au/news-media-claims...
# 1  https://factcheck.aap.com.au/news-media-claims...
# 2  https://factcheck.aap.com.au/news-media-claims...
# 3  https://factcheck.aap.com.au/news-media-claims...
# 4  https://factcheck.aap.com.au/news-media-claims...
#
#                             creativeWork_author_name  \
# 0  Anna Reynolds, Lord Mayor of Hobart, and Counc...
# 1  Assistant Minister for Community Housing and H...
# 2              Independent federal MP Andrew Wilkie.
# 3           NSW Farmers Association CEO Peter Arkle.
# 4      WA Tourism Council chief executive Evan Hall.
#
#   creativeWork_author_sameAs  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
#
#                                  extra_entities_body  \
# 0  [{"id" : 170584",""begin": 76,"end": 88,"entit...
# 1  [{"id" : 6889",""begin": 23,"end": 29,"entity"...
# 2  [{"id" : 962277",""begin": 67,"end": 70,"entit...
# 3  [{"id" : 37335",""begin": 72,"end": 79,"entity...
# 4  [{"id" : 33613",""begin": 96,"end": 113,"entit...
#
#             extra_entities_claimReview_claimReviewed extra_entities_keywords  \
# 0  [{"id" : 3536675",""begin": 36,"end": 46,"enti...                      []
# 1  [{"id" : 6889",""begin": 9,"end": 15,"entity":...                      []
# 2  [{"id" : 962277",""begin": 53,"end": 56,"entit...                      []
# 3  [{"id" : 37335",""begin": 58,"end": 65,"entity...                      []
# 4  [{"id" : 33613",""begin": 82,"end": 99,"entity...                      []
#
#                                  extra_refered_links extra_tags  \
# 0  #h.p_yottUsUom2Qk,https://www.google.com/url?q...        NaN
# 1  #h.p_yottUsUom2Qk,https://www.google.com/url?q...        NaN
# 2  #h.p_yottUsUom2Qk,https://www.google.com/url?q...        NaN
# 3  #h.p_yottUsUom2Qk,https://www.google.com/url?q...        NaN
# 4  #h.p_yottUsUom2Qk,https://www.google.com/url?q...        NaN
#
#                                          extra_title rating_alternateName  \
# 0  Do a quarter of Tasmanians - or 120,000 people...            Ambiguous
# 1  Has the increase in the number of homeless peo...           Misleading
# 2  Has the Tasmanian government been diverting $1...                 True
# 3  Is 90 per cent of NSW drought affected and 30 ...            Ambiguous
# 4  Has there been a significant and sustained dow...          Mostly True
#
#   rating_bestRating rating_ratingValue rating_worstRating
# 0               NaN                NaN                NaN
# 1               NaN                NaN                NaN
# 2               NaN                NaN                NaN
# 3               NaN                NaN                NaN
# 4               NaN                NaN                NaN
#
# [5 rows x 23 columns]

# %%
ix=[i for i in df_new.index if (df_new.at[i,'creativeWork_author_name'] in authors)]
df_filtered = df_new.loc[ix]

# %%
def load_json(js):
    js = re.sub("\",\"\"begin\"" ,",\"begin\"",js)
    js = re.sub("\"\"","\\\"",js)
    return json.loads(js)

def get_wikipedia_url(dictionary):
    base = "https://en.wikipedia.org/wiki/"
    suffix = dictionary['entity'].replace(' ','_')
    return base + suffix

# %%
df_authors['wikipedia'] = ''

# %%
i = 0

for idx in df_authors.index: 
    claims = df_new.loc[df_new['creativeWork_author_name'] == df_authors.at[idx,'author']]
    if (len(claims) > 0):
        js = claims['extra_entities_author'][claims.index[0]]
        if js.strip() != '[]':
            js = load_json(js)
            if len(js) == 1:
                for j in range(len(js)):
                    df_authors.at[idx,'wikipedia'] = get_wikipedia_url(js[j]) 
                i = i + 1

# %% [markdown]
# ### Author classification

# %%
df_authors['type'] = ''

# %%
for idx in df_authors.index:
    title = df_authors.at[idx,'title']
    author = df_authors.at[idx,'author']
    if title is not np.nan:
        if title.find('Democrat') >= 0:
            df_authors.at[idx,'type'] = 'Democrat'
            continue
        if title.find('Republican') >= 0:
            df_authors.at[idx,'type'] = 'Republican'
            continue
        if title.find('Organization') >= 0:
            df_authors.at[idx,'type'] = 'Organization'
            continue
        if ((title.find('Columnist') >= 0) | (title.find('Talk show host') >= 0) | 
        (title.find('Newsmaker') >= 0) | (title.find('Journalist') >= 0)):
            df_authors.at[idx,'type'] = 'Journalist'
            continue
        if ((title.find('Libertarian') >= 0) | (title.find('Green') >= 0) | 
        (title.find('Independent') >= 0) | (title.find('Tea Party') >= 0)):
            df_authors.at[idx,'type'] = 'Political'
            continue
    if author is not np.nan:
        if ((author.lower().find('alliance') >= 0) | (author.lower().find('foundation') >= 0) |
        (author.lower().find('association') >= 0) | (author.lower().find('union') >= 0) |
        (author.lower().find('fund') >= 0) | (author.lower().find('united') >= 0) |
        (author.lower().find('.org') >= 0) | (author.lower().find('club') >= 0) |
        (author.lower().find('committee') >= 0) | (author.lower().find('council') >= 0) |
        (author.lower().find('department') >= 0) | (author.lower().find('party') >= 0)):
            df_authors.at[idx,'type'] = 'Organization'
            continue
    df_authors.at[idx,'type'] = ''

# %%
ix=[i for i in df_authors.index if (df_authors.at[i,'type'] != '')]
df_authors.loc[ix].shape
#1170 authors classified with simple politifact heuristic
# Out:
# (1207, 5)

# %%
ix=[i for i in df_authors.index if ((df_authors.at[i,'type'] == '') & (df_authors.at[i,'wikipedia'] != ''))]
df_authors.loc[ix].shape
#630 authors with wikipedia link and no type from politifact
# Out:
# (604, 5)

# %%
def get_political_party(entity):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setQuery("""
    prefix dbr: <http://dbpedia.org/resource/>
    prefix dbo: <http://dbpedia.org/ontology/>

    select distinct ?party where 
    {
    <http://dbpedia.org/resource/%s> dbo:party ?party.
    <http://dbpedia.org/resource/%s> a dbo:Person. 
    } 
    """ % (entity,entity))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    if len(results["results"]["bindings"]) == 1:
        return results["results"]["bindings"][0]["party"]["value"]
    else:
        return None

# %%
# Don_Balfour_(politician)
get_political_party('Barack_Obama')
# Out:
# 'http://dbpedia.org/resource/Democratic_Party_(United_States)'

# %%
for i in ix:
    author = df_authors.at[i,'wikipedia']
    author = author[30:]
    party = get_political_party(author)
    
    if party is not None:
        if party.find('Democratic') >= 0:
            df_authors.at[i,'type'] = 'Democrat'
            continue
        if party.find('Republican') >= 0:
            df_authors.at[i,'type'] = 'Republican'
            continue
        df_authors.at[i,'type'] = 'Political'

# %%
ix=[i for i in df_authors.index if ((df_authors.at[i,'type'] == '') & (df_authors.at[i,'wikipedia'] != ''))]
df_authors.loc[ix].shape
#454 authors with wikipedia link and no political party
# Out:
# (428, 5)

# %%
display(df_authors.loc[ix])
# Out:
#                            author                     title  \
# 3              Secure America Now                       NaN
# 5                        Yes on 8         None from Florida
# 11                     Glenn Beck  The PolitiFact scorecard
# 14                Michael M. Crow                       NaN
# 20                   Sean Hannity  The PolitiFact scorecard
# ...                           ...                       ...
# 2059                 Recovery.gov                       NaN
# 2060                 Mary Matalin                       NaN
# 2062              Michelle Malkin        None from Colorado
# 2064  House Republican Conference                       NaN
# 2066                   Fred Smith                       NaN
#
#                                             description  \
# 3     Secure America Now is an independent, non-prof...
# 5     "Yes on 8 Florida" is a group urging residents...
# 11    Glenn Beck is the host of The Glenn Beck Progr...
# 14    Michael M. Crow is Arizona State University's ...
# 20    Sean Hannity is a conservative political comme...
# ...                                                 ...
# 2059  Recovery.gov is the U.S. government's official...
# 2060  Mary Matalin is a Republican political consult...
# 2062  Malkin is a prominent conservative blogger and...
# 2064                                                NaN
# 2066         Chair and Chief Executive Officer of FedEx
#
#                                               wikipedia type
# 3      https://en.wikipedia.org/wiki/Secure_America_Now
# 5     https://en.wikipedia.org/wiki/California_Propo...
# 11             https://en.wikipedia.org/wiki/Glenn_Beck
# 14        https://en.wikipedia.org/wiki/Michael_M._Crow
# 20           https://en.wikipedia.org/wiki/Sean_Hannity
# ...                                                 ...  ...
# 2059  https://en.wikipedia.org/wiki/American_Recover...
# 2060         https://en.wikipedia.org/wiki/Mary_Matalin
# 2062      https://en.wikipedia.org/wiki/Michelle_Malkin
# 2064  https://en.wikipedia.org/wiki/United_States_Ho...
# 2066  https://en.wikipedia.org/wiki/Fred_Smith_(bass...
#
# [428 rows x 5 columns]

# %%
#is organization
def is_organization(entity):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setQuery("""
    prefix dbr: <http://dbpedia.org/resource/>
    prefix dbo: <http://dbpedia.org/ontology/>

    ask where 
    {
    <http://dbpedia.org/resource/%s> a dbo:Organisation. 
    } 
    """ % entity)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results['boolean']

# %%
for i in ix:
    author = df_authors.at[i,'wikipedia']
    author = author[30:]
    if is_organization(author) == True:
        df_authors.at[i,'type'] = 'Organization'

# %%
ix=[i for i in df_authors.index if ((df_authors.at[i,'type'] == '') & (df_authors.at[i,'wikipedia'] != ''))]
df_authors.loc[ix].shape
#367 authors unclassified authors with wikipedia link
# Out:
# (354, 5)

# %%
# for i in ix:
#     print(df_authors.at[i,'author'])

# %%
#is person
def is_person(entity):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setQuery("""
    prefix dbr: <http://dbpedia.org/resource/>
    prefix dbo: <http://dbpedia.org/ontology/>

    ask where 
    {
    <http://dbpedia.org/resource/%s> a dbo:Person. 
    } 
    """ % entity)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results['boolean']

# %%
for i in ix:
    author = df_authors.at[i,'wikipedia']
    author = author[30:]
    if is_person(author) == True:
        df_authors.at[i,'type'] = 'Person'

# %%
#ix=[i for i in df_authors.index if ((df_authors.at[i,'type'] == '') & (df_authors.at[i,'wikipedia'] != ''))]
ix=[i for i in df_authors.index if ((df_authors.at[i,'type'] == ''))]
df_authors.loc[ix].shape
# Out:
# (393, 5)

# %%
for i in ix:
    print('entity: %s, description: %s\n' % 
    (df_authors.at[i,'author'],df_authors.at[i,'description']))
# Out:
# entity: Our Democracy 2020, description: Our Democracy 2020 is a Madison-based coalition that formed in 2015 to push for voting rights and other government and election reforms.
#
# entity: Secure America Now, description: Secure America Now is an independent, non-profit group that claims 2 million members of all political stripes, united behind "policies that will protect our nation against terrorist infiltration, attack and capitulation to our enemies."
#
# entity: Vote NO on 8, description: The Vote NO on 8 group is urging Florida residents to vote against Amendment 8, the class size amendment.
#
# entity: Yes on 8, description: "Yes on 8 Florida" is a group urging residents to vote in favor of Amendment 8, which would change a 2002 amendment about class sizes.
#
# entity: Wisconsin Jobs Now, description: Wisconsin Jobs Now is an advocacy group involved on jobs and education issues. It describes itself as "a non-profit organization committed to fighting income inequality from the bottom up and building stronger communities throughout Wisconsin."
#
# entity: R2RMerge, description: R2RMerge is a student movement from Rutgers University-Camden. The group opposes the planned merger of Rutgers-Camden with Rowan University.
#
# entity: Chain email, description: Chain emails circulate on the Internet, usually anonymously, making a variety of political claims.
#
# entity: Mike Gallagher, description: Republican Mike Gallagher of Green Bay was elected to the U.S. House of Representatives in November 2016. He is the senior global market strategist at Breakthrough Fuel, a Green Bay supply chain fuel management company. Gallagher previously served as a human intelligence and counterintelligence officer in the U.S. Marine Corps. He was a foreign policy aide to GOP Wisconsin Gov. Scott Walker's 2016 presidential campaign.
#
# entity: EmpowerED Georgia, description: EmpowerED Georgia is an organization of an estimated 3,500 parents, students and teachers that aims to improve Georgia's public education system.
#
# entity: Tom Bossert, description: Tom Bossert, a former national security aide to President George W. Bush, serves as President Donald Trump's homeland security adviser.
#
# entity: Bloggers, description: nan
#
# entity: world-newss.com, description: nan
#
# entity: Kelda Helen Roys, description: Kelda Helen Roys, a Madison Democrat, was elected to the Wisconsin Assembly in 2008 and served until 2012. In 2012, she lost to Mark Pocan in the race for the Democratic nomination for the U.S. House of Representatives. She is running for the Democratic nomination for governor in 2018. An attorney, Roys is the former executive director of NARAL Pro-Choice Wisconsin, which supports abortion rights.
#
# entity: Hunter Schwarz, description: Hunter Scwarz is a reporter for the Washington Post.
#
# entity: Sid Covington, description: Businessman Sid Covington of Austin chairs the board of the Lone Star Rail District, based in San Marcos, Texas, is a public agency with a focus on developing a regional passenger rail line connecting San Antonio to Georgetown, north of Austin.
#
# entity: Jimmy Flannigan, description: Jimmy Flannigan, a 2016 candidate for the District 6 seat on the Austin City Council, also ran for the post in 2014. He says on his campaign website he's a small businessman and community leader.
#
# entity: AmeriPAC, description: AmeriPAC is a political action committee that largely supports conservative Republican candidates.
#
# entity: Kenneth Block, description: Kenneth Block is a software engineer and president of Simpatico Software Systems. He founded Rhode Island's Moderate Party and ran unsuccessfully for governor in 2010. He switched to the Republican Party in 2013 and made an unsuccessful run for Rhode Island Governor in 2014.
#
# entity: Impact America Action, description: nan
#
# entity: Conservative Stories, description: Conservative Stories is a rightwing website.
#
# entity: Ralph Reed, description: Ralph Reed is a conservative political strategist and is founder and chairman of the Faith & Freedom Coalition.
#
# entity: We Are Milwaukee, description: We Are Milwaukee, which is registered with the Wisconsin Government Accountability Board as a political committee, says it works for "social and economic justice."
#
# entity: James Quintero, description: James Quintero of the conservative-leaning Texas Public Policy Foundation says he's focused his research efforts on: state & local government spending, debt, taxes, financial transparency, annexation, and pension reform.
#
# entity: Anne Goodman, description: Anne Goodman is the executive director and CEO of the Cleveland Foodbank, which provides food for 450 meal sites, shelters and pantries.
#
# entity: Mark Geist, description: Mark "Oz" Geist was a member of the security team at the CIA annex in Benghazi, Libya, during the attack on the U.S. consulate in 2012.
#
# entity: Ron Shipman, description: Ron Shipman is the vice president of environmental affairs at Georgia Power. Shipman directs the company’s environmental stewardship and compliance programs to meet or surpass all environmental laws and regulations.
#
# entity: Americans for a Strong Defense, description: Americans for a Strong Defense is a 501(c)4 that opposes the Chuck Hagel nomination for U.S. Secretary of Defense. Its website states its mission as "to promote policies that will ensure the United States remains secure and continues to be in a position to maintain security commitments to our allies."
#
# entity: Americans for Prosperity Georgia chapter, description: Americans for Prosperity's Georgia chapter is a conservative group advocates for limited government, free markets and fiscal and regulatory restraint.
#
# entity: Tammy Hall, description: Tammy Hall, 50, was elected to the Lee County Board of Commissioners District 4 seat in November 2004.  In November 2005, she served as chairwoman, becoming the first woman to chair the board in its 119-year history. Previously, she represented Ward 1 on the Fort Myers City Council.
#
# entity: Tom McCarey, description: Member of the National Motorists Association.
#
# entity: Steve Loomis, description: Steve Loomis is the president of the Cleveland Police Patrolmen's Association.  CPPA serves as the bargaining unit for all non-supervisory patrol officers, detectives, and radio dispatchers in Cleveland and has about 1,450 members.
#
# entity: Charles Odimgbe, description: Charles Odimgbe is the Chief Executive Office of the Rhode Island Public Transit Authority.
#
# entity: Dominick Marino, description: Dominick Marino is president of The Professional Firefighters Association of New Jersey.
#
# entity: Pam Stewart, description: Pam Stewart is a former public school teacher and principal. In 2004, she was named Deputy Chancellor for Educator Quality at the Florida Department of Education. She served in that position until 2009 when she moved to the St. Johns County School District to become Deputy Superintendent for Academic Services. She returned to the department in 2011 as Chancellor of Public Schools. In August 2013, the state Board of Education named her as the interim commissioner after the resignation of Tony Bennett.
#
# entity: With Honor, description: nan
#
# entity: Tweets, description: Twitter is a messaging service where people often discuss politics. Individual messages are called Tweets.
#
# entity: A Stronger Wisconsin, description: nan
#
# entity: Rush Holt, description: U.S. Rep. Rush Holt is a Democrat representing New Jersey's 12th district.
#
# entity: The Freedom Project, description: The Freedom Project is a Republican fundraising operation led by House Republican Leader John Boehner.
#
# entity: The Coalition for Public Schools, description: Group that "represents religious, child advocacy and education organizations."
#
# entity: Debbie Jackow, description: Debbie Jackow, 57, is running for the Lee County Board of Commissioners District 4 seat in November 2010 against incumbent chairwoman Tammy Hall. Jackow now works as a clinical laboratory scientist for Lee Memorial Health System.
#
# entity: Clay Cox, description: Republican Clay Cox is running for U.S. House of Representatives in Georgia's 7th district.
#
# entity: Citizens for Transportation Mobility, description: Citizens for Transportation Mobility is an advocacy group that supports a 1 percent sales tax to pay for transportation projects in Georgia.
#
# entity: Scott Keyes, description: Scott Keyes is a reporter for ThinkProgress.org, a web site of the left-leaning Center for American Progress Action Fund. The fund is run by John Podesta, who served as chief of staff for President Bill Clinton.
#
# entity: Public Notice, description: Public Notice and its Public Notice Research & Education Fund advocate on economic issues and the federal government. Public Notice does not disclose its donors. Public Notice’s executive director, Gretchen Hamel, is a former spokesman for the House Republican Conference.
#
# entity: billhislam.com, description: The website billhislam.com attempts to link Tennessee Gov. Bill Haslam to efforts allowing Islam to influence state public policy and finance.
#
# entity: Americans for Prosperity: Florida, description: Americans for Prosperity Florida is the Florida affiliate of a free-market group that fights "big government."
#
# entity: The Campaign to Fix the Debt, description: nan
#
# entity: Portland Public Schools, description: Portland Public Schools is Oregon's largest school district.
#
# entity: The Trump Talks, description: The Trump Talks is a pro-President Donald Trump website.
#
# entity: Kitty Boitnott, description: Kitty Boitnott was president of the Virginia Education Association, an organization of about 60,000 public school teachers, from 2008 to 2012..
#
# entity: Sam Rashid, description: Sam Rashid is the chief executive officer of HOLTEC USA, which supplies equipment to the lumber industry. He is also involved with several other area businesses. Rashid, of Valrico, is a leading critic of the proposed sales tax increase for transit and roads in Hillsborough County.
#
# entity: Clay Dafoe, description: Tax preparer and Austin mayoral candidate
#
# entity: Progress Florida, description: Progress Florida is a liberal public interest group based in St. Petersburg, Fla.
#
# entity: Eric Hovde, description: Eric Hovde, a hedge fund manager and businessman from Madison, entered politics by running for the Republican nomination for U.S. Senate in 2012. He finished second in the GOP primary.
#
# entity: No Tax For Tracks, description: No Tax For Tracks is a community organization in Pinellas County created to oppose budget increases for the Pinellas Suncoast Transit Authority.
#
# entity: Antiwar.com, description: Antiwar.com is a non-interventionist website division of the Randolph Bourne Institute.
#
# entity: David Pennington, description: David Pennington is mayor of Dalton, Ga.
#
# entity: Rebecca Bell-Metereau, description: nan
#
# entity: Tom Fanning, description: Tom Fanning is the chief executive officer of Southern Co., based in Atlanta. Southern Co. operates in four states and owns Georgia Power. He has been at the company for more than 30 years.
#
# entity: Trebor Banstetter, description: Delta Spokesman.
#
# entity: Choose: New Jersey, description: Choose: New Jersey is a nonprofit organization that markets the state to attract businesses and jobs to New Jersey.
#
# entity: Ann Teich, description: Ann Teich, initially elected to Austin's school board in 2012 and re-elected in 2012, represents District 3.
#
# entity: Jerome Buting, description: Jerome Buting is a criminal defense lawyer based in the Milwaukee suburb of Brookfield, Wis. His past clients include Steven Avery, a Wisconsin man convicted of murder whose case is featured in the 2015 Netflix series "Making A Murderer."
#
# entity: Put Alaska First PAC, description: Put Alaska First is a political action committee supporting Democratic Sen. Mark Begich of Alaska.
#
# entity: David Wyss, description: David Wyss is the chief economist at Standard & Poor’s.
#
# entity: Tom Palzewicz, description: Tom Palzewicz, a Democratic business owner from the Milwaukee suburb of Brookfield, is a 2018 candidate for the U.S. House seat held by Republican Jim Sensenbrenner.
#
# entity: Vicki Saporta, description: Vicki Saporta has been president and CEO of the National Abortion Federation since 1995.
#
# entity: Joe Zepecki, description: Joe Zepecki, a Democrat, is the communications director for Mary Burke's 2014 campaign for governor of Wisconsin.
#
# entity: Mike Tate, description: Mike Tate is chairman of the Democratic Party of Wisconsin. He previously worked for Jim Doyle, the former Wisconsin governor, a public employee union and a voter mobilization organization.
#
# entity: Dream Defenders, description: The Dream Defenders describe themselves as "a human rights organization, directed by Black & Brown youth who confront Inequality & the Criminalizing of our Generation with nonviolent Direct Action and building of collective power in our communities."
#
# entity: Virginia ""Jennie Lou"" Leeder, description: nan
#
# entity: Uber, description: Uber is a ride-sharing service with providers in many cities including Austin.
#
# entity: Mark Tapscott, description: Mark Tapscott is the editorial page editor for the Washington Examiner.
#
# entity: Workers' Voice, description: Workers' Voice is a "super PAC" affiliated with the AFL-CIO
#
# entity: Victoria Taft, description: Victoria Taft is a conservative talk show host on KPAM radio.
#
# entity: Progressive Choice Florida, description: nan
#
# entity: Jason Haas, description: Jason Haas was elected to the Milwaukee County Board in an April 2011 special election. He is a stay-at-home father.
#
# entity: PuppetStringNews.com, description: A website associated with fake news.
#
# entity: Heather McGhee, description: Heather C. McGhee is president of Demos, a group that believes too much political and economic power lies in the hands of too few people
#
# entity: Lowell Holtz, description: Lowell Holtz was a candidate in the spring 2017 primary for the nonpartisan position of State Superintendent of Public Instruction. He's a former principal and school superintendent in multiple Wisconsin school districts.
#
# entity: Occupy Democrats, description: Occupy Democrats, founded in 2012, is an advocacy group created to counterbalance the Republican tea party, and to "give President Obama and other progressive Democrats a Congress that will work with them to grow the economy, create jobs, promote fairness and fight inequality, and get money out of politics!"
#
# entity: Ellen Troxclair, description: Ellen Troxclair, elected in 2014 to represent a Southwest Austin district on the Austin City Council, says she otherwise volunteers in the community and manages a real estate management business.
#
# entity: For Our Future Florida, description: For Our Future Florida is a progressive advocacy group.
#
# entity: Our Principles PAC, description: Our Principles PAC was formed by Katie Packer, a veteran Republican strategist, with the goal of reducting support for Donald Trump.
#
# entity: Viral image, description: Graphics, pictures and charts shared on social media give chain emails a run for their money when it comes to spreading too-good-to-be-true claims all over the Internet. A common form is is the "Internet macro," which uses an easily recognized and repurposed image (called a meme) wth superimposed text to make a funny but political argument. Sometimes these images are passed across social networks like Facebook, Twitter and Reddit so widely that the original source is nearly impossible to determine.
#
# entity: Mike McCabe, description: Mike McCabe, of Madison, is running for the Democratic nomination for governor of Wisconsin in 2018. He was executive director of the non-profit Wisconsin Democracy Campaign, which tracks money in state politics.
#
# entity: Athens Banner-Herald, description: nan
#
# entity: Oregon Lottery, description: The Oregon Lottery provides money for economic development and schools.
#
# entity: George Nee, description: George Nee has been president of the Rhode Island AFL-CIO since September 2009.
#
# entity: Gen. Peter Chiarelli, description: Gen. Peter Chiarelli is the vice chief of staff for the United States Army.
#
# entity: Scot Ross, description: Scot Ross is executive director of the Madison-based One Wisconsin Now, a liberal advocacy group. He formerly worked as a communication director for Democrats who have served in Congress and in Wisconsin state government.
#
# entity: Forbes blog, description: The Forbes blog is an online news blog hosted by Forbes magazine.
#
# entity: Janet Freedman, description: Janet Freedman is a coastal geologist with the Coastal Resources Management Council.
#
# entity: If You Only News, description: If You Only News describes itself as a news-entertainment service.
#
# entity: Bryan Kennedy, description: Bryan Kennedy is president of the Wisconsin chapter of the American Federation of Teachers, known as AFT-Wisconsin, a union that represents professional employees who work for the state or local government. In 2004 and 2006, he ran as a Democrat against U.S. Rep. Jim Sensenbrenner (R-Menomonee Falls).
#
# entity: Wisconsin State AFL-CIO, description: nan
#
# entity: Steve Acenbrak, description: Steve Acenbrak first joined the City of Roswell as its Deputy Transportation Director in 2001. He has more than 28 years of engineering and management experience, according to the city's website. Acenbrak served as Roswell’s Transportation Director from 2002 – 2006. He returned on October 20, 2008, after working two years as the Director of Civil Engineering for Pond & Company.
#
# entity: Alex Jones, description: Alex Jones is a conservative radio show host based in Austin, Texas. He hosts The Alex Jones Show and runs InfoWars.com, a website known to traffic in fake news and conspiracy theories.
#
# entity: Bill Kristol, description: Bill Kristol is the editor at large of the Weekly Standard, a conservative magazine. He previously served as chief of staff to Vice President Dan Quayle during the Bush administration and to Secretary of Education William Bennett under President Reagan.
#
# entity: Alexandria Ocasio-Cortez, description: nan
#
# entity: Stephen Miller, description: Stephen Miller is a senior adviser to President Donald Trump. He wrote many of Trump's daily speeches toward the end of the 2016 presidential campaign. Previously he worked in the Senate office of Alabama Republican Jeff Sessions, who became Trump's attorney general in 2017.
#
# entity: Andy Gronik, description: Democrat Andy Gronik, a businessman who lives in the Milwaukee suburb of Fox Point, announced in July 2017 that he would run for governor of Wisconsin in 2018 in his first run for public office. He dropped out of the race on June 21, 2018.
#
# entity: Calvine Rollins, description: Calvine Rollins is president of the Georgia Association of Educators.
#
# entity: Doonesbury, description: Doonesbury is a Pulitzer Prize-winning comic strip by G.B. Trudeau.
#
# entity: Anthony Tata, description: Anthony Tata is a former Army brigadier general and deputy commanding general of U.S. forces in Afghanistan from 2006-07. He regularly comments on national security to the media, and he is also a novelist.
#
# entity: Keep the Promise 1 PAC, description: Keep the Promise 1 is a PAC supporting Ted Cruz for president.
#
# entity: James Parisi, description: James Parisi is a field representative and lobbyist for the Rhode Island Federation of Teachers and Health Professionals, a union with about 10,000 members in Rhode Island.
#
# entity: Liberals Are Cool, description: Liberals are cool is a website featuring articles, memes and humor items with a Democratic bent.
#
# entity: Robert Malin, description: Robert Malin is a musician and documentary filmmaker from Charlestown. He is active on social justice issues such as poverty and homelessness.
#
# entity: Diane Hurley, description: Diane Hurley is chief executive officer of Newport Grand in Newport. She has worked in various capacities at the business, which her family owns, since it opened in 1976.
#
# entity: Greenville Gazette, description: The Greenville Gazette, a website, appears to collect and repackage news and feature stories.
#
# entity: Brent Larkin, description: Brent Larkin writes a weekly column for The Plain Dealer's Forum section on Sundays. From 1991 until his retirement in 2009, he was director of The Plain Dealer's editorial page.
#
# entity: Pray in Jesus Name Project, description: nan
#
# entity: Jeffrey Grybowski, description: Jeffrey R. Grybowski has been involved with the Deepwater Wind project since 2008, first as an outside lawyer then, as of 2012, chief executive officer. Grybowski formerly was policy director and chief of staff for Rhode Island Governor Donald Carcieri.
#
# entity: David Dooley, description: David Dooley is the president of the University of Rhode Island.
#
# entity: Sensible Transportation Solutions for Austin PAC, description: The Sensible Transportation Solutions for Austin PAC urged voters to reject Proposition 1 on the November 2016 ballot. Its treasurer was Michael Levy of Austin.
#
# entity: Philip Keefe, description: Philip Keefe is president of the Service Employees International Union, Local 580.
#
# entity: Richard Paglia, description: Richard Paglia is a vice president of Houston-based Spectra Energy. His office is in Waltham, Mass.
#
# entity: Dan Micciche, description: Dan Micciche, an attorney, is a member of the Dallas school board.
#
# entity: David Sweetser, description: David C. Sweetser is  the founder and principal of Massachusetts-based High Rock Development LLC. The company owns the Industrial National Bank Building in downtown Providence.
#
# entity: Julia Sass Rubin, description: Julia Sass Rubin is a spokeswoman for the advocacy group Save Our Schools NJ. She also is an associate professor at the Edward J. Bloustein School of Planning and Public Policy at Rutgers University.
#
# entity: Joe Davis, Sr., description: Joe Davis, Sr. is a Milwaukee alderman representing the 2nd District on the city's northwest side. he has announced a bid for Milwaukee mayor in spring of 2016.
#
# entity: Liberal Blogger, description: Liberal blogger
#
# entity: Theresa Price, description: Theresa Price is a board member of Direction Action for Rights and Equality (DARE).
#
# entity: Albert Papp Jr., description: Albert Papp Jr. is president of the New Jersey Association of Railroad Passengers, a transportation advocacy group founded in 1980.
#
# entity: Mallard Fillmore, description: Nationally syndicated comic strip with a conservative viewpoint drawn by Bruce Tinsley. It began in 1994 and stars the eponymous duck, "a seasoned, rumpled ex-newspaper reporter" who "loves to question his colleagues' more liberal-minded views about current affairs," according to the strip's website, www.mallardfillmore.com.
#
# entity: Defend Arizona, description: Defend Arizona is a political action committee. The conservative group says it stands for lower taxes, limited government, a strong military and secure borders.
#
# entity: Marcus Low, description: Marcu Low is the policy director for the Treatment Action Campaign, based in Johannesburg, South Africa.
#
# entity: Infowars, description: Infowars is a conspiracy oriented website run by Alex Jones.
#
# entity: Jobs Ohio, description: JobsOhio is a corporate non-profit set up by the state of Ohio to create jobs and build the state's economy.
#
# entity: Terry Lawler, description: Terry Lawler, a former state lawmaker, is executive director of the Regional Business Coalition of Metropolitan Atlanta
#
# entity: Republican News, description: A blog with Republican-oriented news.
#
# entity: Fix Austin Schools, description: Fix Austin Schools organized in Austin to urge school district residents to support a four-part, $892 million bond package on the May 11, 2013, ballot.
#
# entity: Food & Water Watch, description: nan
#
# entity: Nancy Gordeuk, description: Nancy Gordeuk is the founder of TNT Academy, a non-traditional educational center in Gwinnett County, Georgia
#
# entity: Sarah Copelin-Wood, description: nan
#
# entity: Sheila Resseger, description: Sheila Resseger, of Cranston, Rhode Island, is a retired teacher who taught at the Rhode Island School for the Deaf.
#
# entity: NextGen Climate, description: Billionaire environmentalist Tom Steyer's political action committee, which is non-partisan and attacks politicians who the 501(c)(4) sees as espousing anti-environmental policies.
#
# entity: Americans for Job Security, description: Americans for Job Security is a conservative-leaning issue advocacy group that favors "free markets and pro-paycheck public policy."
#
# entity: Rees Lloyd, description: Rees Lloyd is an attorney who contributes to the blog of Portland talk-radio host Victoria Taft.
#
# entity: Progress Texas, description: On its website, Progress Texas describes itself as a "nonprofit communications hub that educates the public about politicians, policies and organizations that have a direct impact on the everyday lives of Texans." Its mission, according to the website, is "to provide a strong, credible and enduring progressive voice that will ensure more inclusive, just and sustainable policies for Texas."
#
# entity: Marc Molinaro, description: nan
#
# entity: Rick McAllister, description: Rick McAllister is president of the Georgia Retailers Association.
#
# entity: Betsy Miller-Jones, description: nan
#
# entity: Patriotnetwork.one, description: Patriotnetwork.one is a website that posts news critical of Muslims and on other topics.
#
# entity: Coalition to Bring Jobs to R.I., description: nan
#
# entity: David Madland, description: David Madland is the director of the American Worker Project for the liberal-leaning Center for American Progress.
#
# entity: Online petition, description: Stop the Mass Killings of Coyotes is an online petition circulated on Rhode Island's Aquidneck Island. It follows approval by the Middletown Town Council to authorize a hunter to kill coyotes, following complaints from residents.
#
# entity: Building a Better Ohio, description: Building a Better Ohio is a political action committee promoting passage of Issue 2 in Ohio. Passage of the state issue would allow provisions of Senate Bill 5, a law overhauling collective bargaining rules for public workers in Ohio, to be implemented.
#
# entity: Chris Kennedy, description: Chris Kennedy is a businessman and a son of former U.S. Senator Robert F. Kennedy.
#
# entity: New Century Times, description: New Century Times is a website and news aggregator.
#
# entity: City of Atlanta, description: City of Atlanta
#
# entity: Troy LaRaviere, description: Troy LaRaviere is the president of the Chicago Principals and Administrators Association and a former principal of a Chicago elementary school.
#
# entity: Raj Shah, description: Raj Shah is the president of the Rockefeller Foundation and former USAID administrator.
#
# entity: Roger Falk, description: Roger Falk, an Austin resident, has been a volunteer with the Travis County Taxpayers Union.
#
# entity: Nowtrump.com, description: Nowtrump.com is a pro-Trump fake news website.
#
# entity: Meria Carstarphen, description: Meria Joel Carstarphen, superintendent of the Austin Independent School District, was previously superintendent of the Saint Paul (Minn.) Public Schools.
#
# entity: Rainbow/PUSH Coalition, description: The Rainbow PUSH Coalition is a civil rights organization founded by Jesse Jackson. It is based in Chicago.
#
# entity: We Are Ohio, description: We Are Ohio is a citizen-driven, community-based, bipartisan coalition that has come together to repeal Senate Bill 5 in Ohio. The legislation would overhaul rules for collective bargaining by public employees.
#
# entity: Oregon PTA, description: The Oregon PTA is the largest network of parents in Oregon.
#
# entity: Freedom Daily, description: Freedom Daily bills itself as “a forum for discussing meaningful conservative American and world news."
#
# entity: John Scocos, description: John Scocos is the secretary of the Wisconsin Department of Veterans Affairs.
#
# entity: Deborah Gist, description: Deborah A. Gist has been Rhode Island's education commissioner since 2009. She had previously been the education chief in Washington, D.C.
#
# entity: Herb Garrett, description: Herb Garrett is the executive director of the Georgia School Superintendents Association.
#
# entity: Jeffrey Hernandez, description: Jeffrey Hernandez is the chief executive officer of National Academic Educational Partners.
#
# entity: Texas Right to Life, description: nan
#
# entity: Metro Atlanta Voter Education Network, description: The Metro Atlanta Voter Education Network is a coalition of businesses and civic groups that is running a public information campaign to educate voters about a July 2012 transportation referrendum.
#
# entity: One New Jersey, description: One New Jersey is a 501(c)4 advocacy organization that opposes Gov. Chris Christie's policies.
#
# entity:  Save Our City, Milwaukeeans Can't Wait, description: Save Our City, Milwaukeeans Can't Wait registered with the City of Milwaukee in July 2017 as a political committee seeking to recall Milwaukee Mayor Tom Barrett.
#
# entity: Mark S. Zaccaria, description: nan
#
# entity: Robert Flanders, description: Robert G. Flanders Jr. is a former Rhode Island Supreme Court justice, former chairman of the Rhode Island Board of Regents for Elementary and Secondary Education, and former receiver for the city of Central Falls.
#
# entity: North Korean foreign ministry, description: nan
#
# entity: Jim Durrett, description: Jim Durrett is Board Chairman of the Metropolitan Atlanta Rapid Transit Authority.
#
# entity: Robert Mujica, description: Robert Mujica is the Director of the State Division of Budget under Gov. Andrew M. Cuomo.
#
# entity: YourNewsWire.com, description: A website associated with fake news.
#
# entity: Stokes County school teacher, description: His Facebook post went viral.
#
# entity: No Casinos, description: No Casinos is a group that opposes the expansion of gambling.
#
# entity: Vicki Shabo, description: Vicki Shabo is the director of work and family programs at the National Partnership for Women and Families.
#
# entity: Amy Hanauer, description: Amy Hanauer is the founding executive director of Policy Matters Ohio, a policy research institute that examine issues that matter to working families in Ohio. Policy Matters Ohio was founded in January 2000. In 2008, Nation magazine named it the most valuable state or regional organization in the country.
#
# entity: Jennette Gayer, description: Jennette Gayer is staff advocate for Environment Georgia
#
# entity: ForAmerica, description: nan
#
# entity: Mark Brodeur, description: Mark Brodeur is director of tourism at the Rhode Island Economic Development Corporation. A graduate of Johnson & Wales University in Providence, he has worked in the tourism and hospitality industry for 25 years.
#
# entity: BookerFail, description: BookerFail is a website run by American Commitment, a conservative super PAC.
#
# entity: Vicki Martin, description: Vicki Martin is president of Milwaukee Area Technical College. She was named the 10th president of the school in June of 2014, having previously served as the school's executive vice president and provost.
#
# entity: Chicago Public Schools, description: Chicago Public Schools is the third largest school district in the United States.
#
# entity: Marla Stephens, description: Marla Stephens is the head of the appellate division of the Wisconsin state public defender’s office. She was an unsuccessful candidate for the state Supreme Court in spring of 2011, losing in the four-way primary.
#
# entity: J.B. Powell, description: J.B. Powell is a Democratic candidate for Georgia Agriculture commissioner
#
# entity: Austin Independent School District, description: The Austin Independent School District serves Austin, the state capital.
#
# entity: Town hall audience member, description: This unnamed audience member asked Donald Trump a question at a Sept. 17, 2015 town hall in Rochester, N.H.
#
# entity: Daniel Greenfield, description: Daniel Greenfield is an Israeli-born journalist who writes for conservative publications.
#
# entity: Let Freedom Ring, description: Let Freedom Ring is a conservative group.
#
# entity: Leslie Geissler Munger, description: Leslie Geissler Munger was sworn in as Illinois State Comptroller on January 12, 2015. Comptroller Munger is a native Illinoisan, earning her bachelor’s degree at the University of Illinois and her master’s degree from the Kellogg School of Management at Northwestern University.
#
# entity: Texans for Reliable Power, description: Texans for Reliable Power was founded by investor-owned power plants in the state with a focus on on "changing the market structure so there are incentives to build new generation and prevent a reliability crisis and a large increase in blackouts in the years to come," spokesman Eric Bearse told PolitiFact Texas.
#
# entity: Ken Allen, description: Ken Allen is Executive Director of the American Federation of State County and Municipal Employees, Council 75.
#
# entity: Patrick Wales, description: Patrick Wales is project manager for Virginia Uranium Inc., which wants to mine uranium at Coles Hill in Pittsylvania County. Wales was born in Charlottesville and raised in Danville, and he now lives in Danville with his wife, an elementary school teacher, and 3-year-old son. He holds a bachelor’s degree in geology from Radford University and a master’s in geology from the University of Mississippi. He has been with Virginia Uranium since 2007.
#
# entity: Pari Sabety, description: Pari Sabety was Ohio's state budget director under Gov. Ted Strickland.
#
# entity: Sloan Roach, description: Sloan Roach is the executive director of the communications department at Gwinnett County Schools.
#
# entity: Clackamas County Commission, description: The five-member Clackamas County Board of Commissioners govern the county.
#
# entity: Kriner Cash, description: Kriner Cash was hired as superintendent of Memphis City Schools, Tennessee's largest school district, in 2008. He is under contract with MCS until Aug. 1, 2013, at an annual salary of $276,500. Cash previously served as chief of accountability and systemwide performance for Miami-Dade County (Fla.) Public Schools.
#
# entity: Cascade Policy Institute, description: Cascade Policy Institute is a libertarian think tank dedicated to limited government.
#
# entity: Students, Parents and Teachers supporting Marshall Tuck, description: nan
#
# entity: Conservative Republicans of Texas PAC, description: nan
#
# entity: Melissa Johnson, description: Melissa Johnson is a policy analyst with the Georgia Budget and Policy Institute in Atlanta.
#
# entity: Restoration PAC, description: Suburan Chicago-based Restoration PAC is a super PAC that was formed in January 2015.
#
# entity: Florida House Majority Office, description: nan
#
# entity: SEIU Healthcare Illinois & Indiana, description: nan
#
# entity: Snapchat, description: Snapchat is a sociale media messaging platform that allows users to send videos and pictures that will automatically deleted after a few seconds of a person viewing them.
#
# entity: Restore American Freedom and Liberty, description: Denver-based Restore American Freedom and Liberty is a “hybrid” political action committee that is not affiliated with a candidate and can operate as a traditional PAC, contributing funds to a candidate's committee, and as a super PAC, which makes independent expenditures.
#
# entity: Ed Turanchik, description: Ed Turanchik is a candidate for mayor in Tampa's nonpartisan elections on March 1, 2011. He previously served on the Hillsborough County Commission from 1990-98.
#
# entity: David Sciarra, description: David Sciarra is executive director of the New Jersey Education Law Center
#
# entity: Texas Organizing Project, description: The Texas Organizing Project says it works to improve the lives of low-income and working class Texas families through community organizing, and civic and electoral engagement. The group describes itself as a membership-based organization that conducts direct action organizing, grassroots lobbying and electoral organizing led by working families in Texas.
#
# entity: Marty Beil, description: Marty Beil is executive director of the Madison-based Council 24 of the American Federation of State, County and Municipal Employees union, which represents a variety state employees in Wisconsin.
#
# entity: Creative Advocacy Network, description: The Creative Advocacy Network is a group that seeks to expand access to the arts
#
# entity: Texas Future, description: Texas Future says it's an effort dedicated to improving transportation funding in the state.
#
# entity: Center for Western Priorities, description: The Center for Western Priorities is a conservation group based in Colorado.
#
# entity: Lisa Baldelli-Hunt, description: nan
#
# entity: Clayton County Schools, description: The Clayton County school district, which has about 51,000 students, is located just south of Atlanta city limits.
#
# entity: Jennifer Parrish, description: Jennifer B. Parrish, proprietor of Little Learners childcare, Rochester, Minn., campaigns against labor union representation of home-based childcare providers.
#
# entity: Cato Institute, description: The Cato Institute is a non-profit public policy research foundation headquartered in Washington, D.C.
#
# entity: Friends of Greenlight, description: Friends of Greenlight is a pro-transit political action committee dedicated to promoting the Greenlight Pinellas mass transit initiative. Their slogan is "Vote Yes on Greenlight."
#
# entity: Sacramento Bee Editorial Board, description: The editorial board of The Sacramento Bee says it composes editorials that are its collective opinion. It meets regularly to discuss community concerns and issues of the day, it says.
#
# entity: Mario Loyola, description: Mario Loyola is a Senior Fellow at the Texas Public Policy Foundation. Loyola joined the Foundation in July 2010 as founding director of the Center for Tenth Amendment Action, focusing on energy and environment, healthcare, and other federalism issues. He began his career in corporate law. Since 2003, he has focused on public policy, dividing his time between government service and research and writing at prominent policy institutes. He served in the Pentagon as a special assistant to the Under Secretary of Defense for Policy, and on Capitol Hill as counsel for foreign and defense affairs to the U.S. Senate Republican Policy Committee.
#
# entity: Citizens for Lower Taxes and a Stronger Economy, description: A political action committee opposing Florida's proposed Amendment 4.
#
# entity: Paul Saldaña, description: nan
#
# entity: Occupied Wall Street Journal, description: The Occupied Wall Street Journal is a newspaper of the Occupy Wall Street movement.
#
# entity: Salmon for All, description: Salmon for All is based in Astoria and represents commercial gillnetters.
#
# entity: Investor's Business Daily, description: nan
#
# entity: Deepwater Wind, description: Deepwater Wind is a Providence-based company that is developing offshore power-generating wind farm projects. It is planning to build up to 200 wind turbines in Rhode Island Sound that could provide electricity to Rhode Island, Massachusetts and New York.
#
# entity: Campaign to Defend America, description: nan
#
# entity: Sara Stevenson, description: Sara Stevenson, a middle-school librarian in Austin, wrote an op-ed article for the Austin American-Statesman in April 2012.
#
# entity: Randy Bryce, description: Democrat Randy Bryce, an Army veteran, union leader and iron worker, lives in Caledonia in Racine County, Wisconsin. In November 2018, he lost a bid for Wisconsin's 1st District congressional seat, which had been held by U.S. House Speaker Paul Ryan, a Janesville Republican. Bryce also lost races for the Wisconsin Legislature in 2012 and 2014 and lost a 10-way primary for the Racine County Board of Education in 2013.
#
# entity: Bob Donovan, description: Bob Donovan is a Milwaukee alderman, representing a district on the city's south side.  He was elected to the Common Council in 2000. In July 2014 he declared himself a candidate for mayor of Milwaukee in the 2016 election.
#
# entity: Yard sign, description: A yard sign is often made of wood or cardboard and, for our purposes, carries a political message.
#
# entity: Floridians for Solar Choice, description: Floridians for Solar Choice is a political action committee that is collecting signatures to get a question on the 2016 ballot to make it easier for property owners to obtain solar energy.
#
# entity: Bike Austin, description: Bike Austin, an advocacy group, says its mission is to "improves quality of life for all of Austin and Central Texas by growing bicycling as a form of transportation, exercise, and recreation."
#
# entity: Ron Bergeron, description: A Broward County paving contractor who has served as a Florida Fish and Wildlife Conservation Commission commissioner since 2007.
#
# entity: Center for Individual Freedom, description: The Center for Individual Freedom is a conservative political action committee based outside of Washington, D.C. that says its mission is to “protect and defend individual freedoms and individual rights guaranteed by the U.S. Constitution.”
#
# entity: OurLandOfTheFree.com, description: A website associated with fake news.
#
# entity: Nancy Denuccio, description: nan
#
# entity: Marc Schare, description: Marc Schare is a member of the Board of Education for the Worthington City School District in northern Franklin County. The District includes Worthington and portions of Columbus.
#
# entity: Make Us Great Again, description: Make Us Great Again is a super PAC supporting Rick Perry for president.
#
# entity: Allie McCullen, description: Allie McCullen is a statewide organizer with Georgia Students for Public Higher Education and a senior at the University of Georgia.
#
# entity: Terry Jeffrey, description: Terence P. Jeffrey started as editor in chief of CNSNews.com in September 2007. Prior to that, he served for more than a decade as editor of Human Events, where he is now an editor at large.
#
# entity: Family Forward Oregon, description: Family Forward Oregon is an advocacy group that promotes paid family leave, paid sick leave, and greater workplace flexibility for parents.
#
# entity: Charley English, description: Charley English is the director of the Georgia Emergency Management Agency. He began his career in public service in 1980 as a police officer. He was appointed director in 2006.
#
# entity: Brett Bittner, description: Brett Bittner is executive director of the Libertarian Party of Georgia.
#
# entity: Occupy Providence, description: Occupy Providence, an offshoot of the Occupy Wall Street movement, began protesting in the city's Burnside Park since Oct. 15, 2011.
#
# entity: Stand For Children Tennessee, description: Stand For Children is a special-interest group pushing child and education issues.
#
# entity: Occupational Knowledge International, description: Occupational Knowledge International is a nonprofit organization dedicated to improving public health through innovative strategies to reduce exposures to industrial pollutants.
#
# entity: US Political News, description: US Political News posts fake news.
#
# entity: AmericanNews.com, description: AmericanNews.com is a website of undetermined origin.
#
# entity: Ban the Box RI, description: nan
#
# entity: Barney Bishop, description: Barney Bishop is the president and CEO of Associated Industries of Florida, a pro-business group supporting more offshore oil drilling.
#
# entity: James Stegmaier, description: James J. L. Stegmaier has been the Chesterfield County administrator since July 2007. Before that appointment, he was the deputy county administrator for management services beginning in 1997 and the director of the county budget and management department fro 1986-97. Stegmaier graduated from The Catholic University of America, Washington, D.C., in 1976, and also holds a master's degree in public administration from the University of Virginia. He has also attended the Government Finance Officers Association Executive Finance Institute at Georgetown University, Leadership Metro Richmond, and the Senior Executive Institute at the University of Virginia.
#
# entity: Hetty Rosenstein, description: Hetty Rosenstein is the New Jersey director of the Communication Workers of America, the largest union representing state workers.
#
# entity: Carol Hunstein, description: Carol Hunstein is the chief justice of the Georgia Supreme Court.
#
# entity: Sheriff David Clarke for U.S. Senate, description: Sheriff David Clarke for U.S. Senate is an official draft campaign trying to persuade Milwaukee County Sheriff David A. Clarke Jr. to run for a U.S. Senate seat in Wisconsin in 2018.
#
# entity: Ron Book, description: Ron Book is one of the most powerful lobbyists in Florida and lobbies the state Legislature. Based in Aventura in South Florida,  Book represents numerous businesses, associations and local governments including Broward and Miami-Dade counties. He has represented the Miami Dolphins since 1982.
#
# entity: Florida voter, description: These are claims made about politicians from Florida voters that are then repeated in the news media.
#
# entity: Gina Hinojosa, description: Gina Hinojosa of Austin, a civil rights and employment attorney, was elected to Austin's school board in 2012 and elected board president by fellow trustees in January 2015. She stepped down from that position, remaining on the board, to bid successfully for the 2016 Democratic nomination representing Texas House District 49.
#
# entity: Brad Rockwell, description: Austin lawyer Brad Rockwell, who focuses on environmental matters, is former deputy director of the Save Our Springs Alliance.
#
# entity: Jamie Samons, description: Jamie Samons is public affairs manager for the Narragansett Bay Commission, the quasi-public agency that runs Rhode Island's biggest sewage treatment system.
#
# entity: Carl Hosticka, description: Carl Hosticka is a Metro councilor running for Oregon House District 37. He is a Democrat challenging Rep. Julie Parrish, R-West Linn.
#
# entity: Florida Stop Common Core Coalition, description: The Florida Stop Common Core Coalition is a group that opposes Common Core.
#
# entity: Noah Smith, description: Noah Smith is a columnist for Bloomberg View. He was previously an assistant professor of finance at Stony Brook University. He also blogs at Noahpinion.
#
# entity: Elaine Boyer, description: Elaine Boyer, a Republican, is a DeKalb County commissioner
#
# entity: Consumers for Smart Solar, description: Consumers for Smart Solar is a utilities-backed advocacy group promoting Amendment 1, the "Rights of Electricity Consumers Regarding Solar Energy Choice" ballot measure.
#
# entity: Cocks Not Glocks, description: In Cocks Not Glocks, University of Texas students in August 2016 wielded dildos to depict as absurd a state law permitting licensed individuals to bring concealed handguns into campus buildings including classrooms.
#
# entity: Safe Routes to Schools, description: nan
#
# entity: Back to Basics, description: nan
#
# entity: Pete Winstead, description: Winstead, an Austin-area attorney practicing business law, has long been active in regional politics on issues including transportation.
#
# entity: American Federation for Children, description: The American Federation for Children is an interest group focused on education issues, including supporting school choice and voucher initiatives.
#
# entity: Babylon Bee, description: The Babylon Bee describes itself as"your trusted source for Christian news satire."
#
# entity: Texans for America's Future PAC, description: Texans for America's Future, founded to prevent the election of Rick Perry as president, says its latest focus is on electing Democrats in Houston and Harris County.
#
# entity: Michael Tyler, description: Michael W. Tyler is Chariman of the Metropolitan Atlanta Rapid Transit Authority's Board of Directors.
#
# entity: UN's UNICEF, description: nan
#
# entity: Chris Garrett and Bill Kennemer, description: nan
#
# ...
#
# entity: Sarah Huckabee Sanders, description: Sarah Huckabee Sanders was named White House press secretary in July 2017. The daughter of former Arkansas Gov. Mike Huckabee, she was a surrogate for Donald Trump's presidential campaign.
#
# entity: Curtis Foltz, description: Curtis Foltz is executive director of the Georgia Ports Authority.
#
# entity: Mickie Williams, description: nan
#
# entity: John Bolton SuperPAC, description: The John Bolton SuperPAC is run by John Bolton, the Republican political adviser and former U.N. ambassador.
#
# entity: Protect American Jobs, description: Protect American Jobs is a 501(c)4 group that has aired television ads opposing a repeal of Wisconsin's prevailing wage law.
#
# entity: Stephen Kretzmann, description: nan
#
# entity: Vet TV, description: Vet TV was founded by Donny O’Malley, a humorist and YouTube celebrity. According to his bio, O’Malley was a Marine infantry officer for almost six years, serving in Asia and Afghanistan and reaching the rank of captain. The project dubs itself “the Comedy Central of the military.”
#
# entity: People's Majority, description: People's Majority is a super PAC with a post office box in Alexandria, Virginia, organized to defeat U.S. Sen. Sheldon Whitehouse.
#
# entity: James Rockall, description: James Rockall is CEO and Managing Director of World LPG Association.
#
# entity: National Partnership for Women & Families, description: nan
#
# entity: Wannabe Entertainment, description: A website associated with misleading news.
#
# entity: Independent Texans, description: The political action committee's website says it supports ballot measures and candidates, regardless of party, favoring political reform and fiscal reform or issues of oncern to voters in their jurisdiction. The committee was founded in 2001 by director Linda Curtis.
#
# entity: Peter Feigin, description: Peter Feigin is president of the Milwaukee Bucks.
#
# entity: Deadspin, description: Deadspin is an eight-year-old website that brings a humorous and sarcastic attitude to sports news. It is owned by Gawker Media.
#
# entity: Paul Doughty, description: Paul Doughty is president of Local 799 of the International Association of Firefighters, which represents workers in the Providence Fire Department.
#
# entity: Friends of Miami First, description: Friends of Miami First is a political action commission funded by t he Miami Dolphins and the South Florida Stadium LLC, team owner Stephen Ross' company which owns the stadium.
#
# entity: National Federation of Independent Business-Virginia, description: nan
#
# entity: Susan Cole, description: Susan A. Cole has served as the president of Montclair State University since 1998.
#
# entity: Metropolitan North Georgia Water Planning District, description: The Metropolitan North Georgia Water Planning District sets policy, creates plans and promotes coordination for all water issues in a 15-county region in and around metro Atlanta.
#
# entity: Mr. Conservative, description: Mr. Conservative is a conservative website.
#
# entity: Mark Daniels, description: Mark Daniels is a vice president of Hilex Poly Co.
#
# entity: Peter Pantuso, description: Peter J. Pantuso is president and chief executive officer of the American Bus Association, North America's largest motorcoach, tour and travel association. Pantuso oversees the association's daily operations, including government affairs; policy; communications; meetings and education programs.
#
# entity: Charlotte Lehan, description: Charlotte Lehan was elected to the Clackamas County Board of Commissioners in November 2008 and appointed chair in March 2011. Prior to joining the board of commissioners, she was mayor of Wilsonville for 12 years.
#
# entity: Florida Wildlife Federation, description: The Florida Wildlife Federation is a private, non-profit organization that focuses on preserving, managing, and improving Florida's wildlife environment. It is affiliated with the National Wildlife Federation.
#
# entity: Joy Pullmann, description: Joy Pullmann is managing editor of The Federalist and an education research fellow at The Heartland Institute.
#
# entity: Frank Annunziato, description: Frank R. Annunziato is executive director of the University of Rhode Island chapter of the American Association of University Professors, a labor union and advocacy group.
#
# entity: LIBRE Initiative, description: The LIBRE Initiative is a conservative grassroots organization that targets Hispanic voters. It is a a 501(c)4 nonprofit and has ties to the Koch brothers.
#
# entity: Jeff Dickerson, description: Jeff Dickerson is a spokesman for Citizens for Transportation Mobility.
#
# entity: Ridesharing Works for Austin, description: Ridesharing Works for Austin raised the signatures needed to place Proposition 1 on Austin's May 7, 2016 ballot. If approved, the proposition would require the city to accept name-based background checks of drivers for ride-hailing services conducted by the services. If rejected, such drivers would be required to undergo fingerprinting and national background checks run through the FBI.
#
# entity: Environmental Justice League of R.I, description: nan
#
# entity: Good Jobs First, description: Good Jobs First is a research and policy group that argues against corporate tax breaks.
#
# entity: NJ-CAN, description: nan
#
# entity: Don McIntire, description: Don McIntire is a veteran tax activist who lobbies for limited government and limited public spending.
#
# entity: John Ludlow, description: Wilsonville businessman John Ludlow is running for Clackamas County Commission Chair.
#
# entity: Patriot Majority PAC, description: Patriot Majority PAC is a liberal group that has been running ads against Republican candidates in the 2010 election.
#
# entity: US Uncut, description: US Uncut is an activist group that ties corporate tax avoidance to shortages of funds to pay for social services.
#
# entity: Greg Casar, description: Gregorio "Greg" Casar was initially elected to the Austin City Council in 2014. He represents the city's District 4.
#
# entity: Citizens for the Republic, description: Citizens for the Republic is a conservative advocacy group headed by several veterans of the Reagan Administration.
#
# entity: Rosemary Laird, description: Rosemary Laird is a geriatrician at the Centre for Senior Health in Winter Park, Fla.
#
# entity: Patriot Majority USA, description: Patriot Majority USA describes itself as an organization hoping to empower all Americans. Its action plan includes providing more money for public schools, improving the nation’s roads and bridges, supporting the federal health care law’s provision that allows parents to keep their children on their insurance until the age of 26, and closing tax loopholes for special-interest groups.
#
# entity: Drew Springer, description: Freshman state representative in the 2013 Texas Legislature from the Northwest Texas town of Muenster, representing District 68.
#
# entity: Miami-Dade County, description: nan
#
# entity: AFL-CIO of New Jersey, description: nan
#
# entity: Kathy Miller, description: Kathy Miller is president of the Texas Freedom Network, which describes itself as a watchdog group that monitors "far-right issues, organizations, money and leaders."
#
# entity: Kurt Bauer, description: Kurt Bauer is president of Wisconsin Manufacturers & Commerce, the state's largest business lobby.
#
# entity: Anonymous GOP critics, description: nan
#
# entity: Bill Weimer, description: Bill Weimer is the vice president of Youngstown, Ohio,-based Phantom Fireworks, the nation's largest retailer of consumer fireworks.
#
# entity: Robert Koons, description: Robert Koons is a philosophy professor at the University of Texas at Austin.
#
# entity: Environment New Jersey, description: Environment New Jersey is a statewide, citizen-based environmental advocacy group.
#
# entity: Kevin Downing, description: Kevin Downing is an attorney based in Washington, D.C. His highest-profile client is Paul Manafort, who was prosecuted by Special Counsel Robert Mueller.
#
# entity: Russia Today, description: Russia Today is a American cable network that is funded by the government of Russia.
#
# entity: Various media reports, description: this is for hate crimes story. fact-check of reports in news media.
#
# entity: Clean Virginia, description: Clean Virginia is a non-profit organization seeking to overhaul the state's system of regulating power companies, which it says is "corrupt," and "rigged" against  consumers. The organization notes that Virginia's two dominant power companies, Dominion Energy and the Appalachian Power Co., which provide 82 percent of the state's electricity, have contributed more than $12 million to state campaigns since 1996. Those contributions, the organization contends, have reseulted in favorable treatment by the Genral Assembly.
#
# entity: Jeff Tarte, description: Jeff Tarte is a Cornelius Republican in the State Senate.
#
# entity: Elizabeth Foley, description: Foley is a Professor of Law at Florida International University College of Law, a public law school located in Miami, Florida.
#
# entity: Tom Luce, description: Tom Luce, a Dallas lawyer, is a long-time adviser to state government leaders. In the 1980s, he helped steer into law an overhaul of state education laws including the no-pass, no-play requirement that students pass their classes to participate in extracurricular activities.
#
# entity: Glenna Hodge, description: Glenna Hodge, a Spicewood lawyer, made a claim about what the Austin district teaches children about gender identity.
#
# entity: Social Media, description: logo
#
# entity: No on 56 campaign, description: The No on 56 campaign opposes California's proposed $2 per pack cigarette tax. It is funded by tobacco companies Phillip Morris and R.J. Reynolds.
#
# entity: No on 67, description: The No on 67 campaign opposes California's Proposition 67, a measure that would ban thin plastic carryout bags at grocery stores statewide and impose a 10 cent fee on paper and other carryout bags. The campaign is led by a plastics industry trade association.
#
# entity: Viral media reports, description: this is for facebook post and twitter feeds
#
# entity: State Public Service Announcement, description: working on keeping traffic deaths down
#
# entity: Internet commenters, description: People who post comments on stories published on the Internet
#
# entity: State Farm Insurance, description: major insurer
#
# entity: Russell McMurry, description: Russell McMurry is commissioner of the Georgia Department of Transportation.
#
# entity: Viral BuzzFeed, description: buzzfeed.com
#
# entity: Atlanta Journal-Constitution, description: nan
#
# entity: Alan Essig, description: Alan Essig is the longtime executive director of the left-leaning Georgia Budget & Policy Institute.
#
# entity: Claire Suggs, description: education analyst
#
# entity: Joy Reid, description: Joy Reid is the host of MSNBC's The Reid Report.
#
# entity: Stu Burguiere, description: Steve "Stu" Burguiere is the head writer of The Glenn Beck Program
#
# entity: Anissa Naouai, description: Anissa Naouai is a correspondent for RT.
#
# entity: Seneca Jones, description: Aaron Jones founded Seneca Jones sawmill in Eugene in 1954. The company continues to operate several wood products-based businesses in the Eugene area.
#
# entity: David Brooks, description: David Brooks is a columnist for the New York Times.
#
# entity: Joseph Henchman, description: Joseph Henchman is an attorney and policy analyst with The Tax Foundation.
#
# entity: Texas secession petition, description: nan
#
# entity: Bill Powers, description: William Powers Jr., president of the University of Texas at Austin since February 2006,  previously served as dean of the university's School of Law, whose faculty he joined in 1977.
#
# entity:  Our Portland, Our Schools, description: "Our Portland, Our Schools" is a group supporting a Portland Public Schools' bond measure on the November 2012 ballot.
#
# entity: John G. Morgan, description: Morgan had been Deputy to the Governor of the State of Tennessee since January 2009; prior to that, he had served as Comptroller of the Treasury for the State of Tennessee for 10 years. His public service career dates back to 1976 except for a brief stint in the late 1980s with Third National Bank. Morgan has had a longtime interest in and commitment to education. He holds a Bachelor of Science degree in political science and history from Austin Peay State University.
#
# entity: Lights For Liberty, description: Lights for Liberty is a group opposed to the regional transportation tax that goes before metro Atlanta voters on July 31, 2012.
#
# entity: Steve Phelps, description: Steve Phelps is chief marketing officer for NASCAR.
#
# entity: Conservative Voters of Texas PAC, description: Political action committee whose president is Houston attorney Mark McCaig.
#
# entity: Transportation Leadership Coalition, description: Transportation Leadership Coalition opposes a referrendum to raise sales taxes by one cent across metro Atlanta to pay for a transportation overhaul. The vote takes place July 31, 2012.
#
# entity: Anonymous Flier, description: This anonymous flier was passed out at a Fayette County Commission workshop April 4, 2012.
#
# entity: David A. Clarke Jr., description: David A. Clarke Jr., who served as Milwaukee County sheriff from 2002 to 2017, is a senior advisor to the pro-Donald Trump America First Action Super PAC
#
# entity: Oregon Transformation Project, description: The Oregon Transformation Project was started by Republicans in 2010 to transform the way Oregon talks about budget and spending.
#
# entity: David Mellon, description: David Mellon is President of the Rhode Island Brotherhood of Correctional Officers, which represents 1,300 correctional officers, stewards, inmate industries’ supervisors, office personnel, and medical and social work professionals at the Adult Correctional Institutions in Cranston.
#
# entity: Paul Valletta, description: Paul Valletta Jr. is a firefighter and a lobbyist for the Rhode Island State Association of Firefighters.
#
# entity: Alberto Carvalho, description: Alberto Carvalho is the superintendent for Miami-Dade Public Schools, the nation's fourth-largest school district.
#
# entity: Lisa Hamler-Fugitt, description: nan
#
# entity: James Cenerini, description: James Cenerini is the legislative affairs/political action coordinator for Council 94, Rhode Island's largest state and municipal employees union.
#
# entity: John Buss, description: John Buss is the water resources manager for the city of Tallahassee.
#
# entity: General Beauregard Lee, description: nan
#
# entity: DeKalb County, description: DeKalb County, which includes a portion of the city of Atlanta, is Georgia's third highest-populated county.
#
# entity: Bumper Sticker, description: A bumper sticker seen on the back of a Volkswagen VR6 in Washington, D.C.
#
# entity: Citizens for a Progressive Wisconsin, description: Citizens for a Progressive Wisconsin is an interest group that has been active in state-level politics. According to the Center for Responsive Politics, the liberal organization is primarily active in federal politics.
#
# entity: Georgia politicians, description: Various.
#
# entity: Daniel Senor, description: Daniel Senor is a former foreign policy advisor in the administration of George W. Bush and senior advisor to the Coalition Provisional Authority in Iraq. He was previously foreign policy and communications aide in the U.S. Senate. He is a founding partner of Rosemont Capital.
#
# entity: Recovery.gov, description: Recovery.gov is the U.S. government's official website providing access to data related to the American Recovery and Reinvestment Act of 2009.
#
# entity: House Republican Conference, description: nan
#
# entity: The Other 98%, description: The Other 98% is an activist organization that favors an increase in the minimum wage and opposes favorable tax treatment for large corporations.
#
# entity: Local 799 of the International Assoc. of Fire Fighters, description: nan
#
# entity: nan, description: nan

# %%
ix=[i for i in df_authors.index if ((df_authors.at[i,'type'] != ''))]
df_authors.loc[ix].shape
#1683 classified authors
# Out:
# (1683, 5)

# %%
rows = list()
header = ["author","type"]
rows.append(header)

for i in ix:
    row = [df_authors.at[i,'author'],df_authors.at[i,'type']]
    rows.append(row)

with open('Data/authors_classified.csv','w',newline='',encoding="utf-8") as writeFile:
    writer = csv.writer(writeFile,delimiter=',')
    writer.writerows(rows)
    writeFile.close()

# %% [markdown]
# ### Read author dictionary

# %%
#Read authors dictionary
import csv

authors_dict = dict()

with open('Data/authors_classified.csv', 'r', newline='') as file:
    reader = csv.reader(file)
    next(reader)  # Skip header row.
    for row in reader:
        authors_dict[row[0]] = row[1]
