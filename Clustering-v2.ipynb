# %% [markdown]
# ### Imports

# %%
import pickle
import pandas as pd
import numpy as np
import collections
import nltk

from rdflib import Graph
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from matplotlib import pyplot as plt
from sklearn.preprocessing import normalize

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans

from openpyxl import Workbook

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv('Data/data.csv',sep=";")
display(df.head())
# Out:
#                                                  uri        date  \
# 0  http://data.gesis.org/claimskg/creative_work/9...  03/26/2055
# 1  http://data.gesis.org/claimskg/creative_work/e...  03/26/2020
# 2  http://data.gesis.org/claimskg/creative_work/d...  12/10/2019
# 3  http://data.gesis.org/claimskg/creative_work/0...  12/03/2019
# 4  http://data.gesis.org/claimskg/creative_work/f...  11/27/2019
#
#                                                claim  \
# 0  California’s Prop 55 'prevents $4 billion in n...
# 1  Says an election clerk in Green Bay refused to...
# 2  'Queen Elizabeth removes Obamas from royal wed...
# 3  Says state schools superintendent candidate Do...
# 4  'The Walton family, which owns Wal-Mart, contr...
#
#                                             keywords organization   rating
# 0                           education,state finances   politifact  MIXTURE
# 1  bipartisanship,city government,education,elect...   politifact  MIXTURE
# 2                                          fake news   politifact    FALSE
# 3  corporations,education,small business,state bu...   politifact  MIXTURE
# 4           corporations,economy,income,labor,wealth   politifact     TRUE

# %% [markdown]
# ### Get Vocabulary

# %%
keywordDict = dict()
for index, row in df.iterrows():
    keywords = [x.strip() for x in row.keywords.split(',')]
    for keyword in keywords:
        if keyword in keywordDict:
            keywordDict[keyword] += 1
        else:
            keywordDict[keyword] = 1

print("There's a total of %d keywords after lemmatizing" % len(keywordDict))
# Out:
# There's a total of 8883 keywords after lemmatizing

# %%
#Sort dict by occurrences
sorted_dict = sorted(keywordDict.items(), key=lambda kv: kv[1])
sorted_dict = collections.OrderedDict(sorted_dict)

n_occurrences = 50

#Keep keywords with n or more ocurrences
for key in list(sorted_dict):
    if sorted_dict[key] < n_occurrences:
        del sorted_dict[key]

keywordList = list(sorted_dict)
print("There's a total of %d keywords after removing keywords that occur in less than %d claims" % (len(sorted_dict),n_occurrences))
# Out:
# There's a total of 159 keywords after removing keywords that occur in less than 50 claims

# %%
for key, value in sorted_dict.items():
    print("%s: %d" % (key,value))
# Out:
# tourism: 50
# reader suggestion: 50
# space: 51
# sona: 51
# employment: 51
# melania trump: 52
# statistic: 52
# ebola: 53
# satire: 53
# trump: 53
# gun: 53
# fact check: 53
# recreation: 54
# cpc: 54
# russia: 54
# alcohol: 55
# woman: 55
# message machine 2014: 56
# racism: 57
# the last line of defense: 58
# america 's last line of defense: 59
# your news wire: 59
# gun control: 59
# election: 59
# pensions: 60
# conspiracy theory: 60
# fauxtography: 62
# jacob zuma: 62
# state government spending: 63
# president trump: 63
# something for nothing: 63
# weather: 64
# oil spill: 65
# television: 66
# pop culture: 67
# afghanistan: 67
# crusader habit: 67
# radio & tv: 68
# animals: 69
# county budget: 71
# israel: 74
# county government: 76
# human rights: 77
# new hampshire 2012: 77
# marriage: 77
# bernie sander: 77
# viral video: 77
# debates: 81
# sexuality: 82
# natural phenomena: 82
# music: 84
# development: 86
# wealth: 88
# congressional rules: 88
# population: 88
# infrastructure: 91
# hoax: 91
# movies: 91
# china: 93
# florida: 96
# welfare: 97
# world news daily report: 101
# muslim: 101
# small business: 102
# negative campaigning: 102
# politics: 102
# veterans: 103
# retirement: 104
# nuclear: 105
# transparency: 108
# unions: 108
# city budget: 110
# islam: 110
# this week - abc news: 120
# sports: 121
# bipartisanship: 122
# facebook: 122
# science: 123
# technology: 130
# agriculture: 130
# government: 130
# water: 131
# financial regulation: 134
# election 2016: 140
# diversity: 148
# marijuana: 148
# gays and lesbians: 155
# housing: 158
# drugs: 159
# iraq: 161
# civil rights: 162
# medicaid: 162
# families: 164
# regulation: 167
# trump administration: 167
# supreme court: 168
# debt: 176
# health: 176
# animal: 180
# trade: 184
# city government: 194
# polls and public opinion: 197
# corporations: 200
# social security: 200
# government efficiency: 201
# public safety: 215
# stimulus: 226
# religion: 229
# not necessarily the news: 241
# climate change: 243
# ethics: 254
# message machine 2010: 256
# income: 261
# labor: 262
# pundits: 267
# government regulation: 272
# voting record: 274
# deficit: 275
# poverty: 282
# hillary clinton: 282
# medicare: 286
# homeland security: 287
# campaign finance: 288
# children: 296
# women: 299
# message machine 2012: 322
# barack obama: 328
# congress: 333
# state finances: 359
# corrections and updates: 359
# states: 364
# public health: 368
# transportation: 373
# job accomplishments: 383
# workers: 390
# criminal justice: 406
# abortion: 409
# terrorism: 447
# military: 458
# energy: 525
# environment: 535
# guns: 536
# legal issues: 577
# history: 605
# foreign policy: 729
# fake news: 854
# crime: 890
# candidate biography: 906
# donald trump: 924
# elections: 979
# state budget: 979
# federal budget: 1029
# jobs: 1037
# immigration: 1086
# education: 1216
# taxes: 1467
# economy: 1714
# health care: 1719
# asp article: 3311

# %%
def get_keyword_provenance(sorted_dict):
    organization_dict = dict.fromkeys(sorted_dict)
    for index, row in df.iterrows():
        keywords = [x.strip() for x in row.keywords.split(',')]
        author = row.organization
        for keyword in keywords:
            if keyword in organization_dict:
                if organization_dict[keyword] == None:
                    organization_dict[keyword] = author
                else:
                    if organization_dict[keyword].find(author) == -1:
                        organization_dict[keyword] += ', ' + author
    return organization_dict

# %%
organization_dict = get_keyword_provenance(sorted_dict)

for key, value in organization_dict.items():
    print("%s: %s" % (key,value))
# Out:
# tourism: politifact, snopes, africacheck
# reader suggestion: africacheck
# space: politifact, snopes
# sona: africacheck
# employment: africacheck
# melania trump: snopes
# statistic: africacheck
# ebola: politifact, snopes, africacheck
# satire: snopes
# trump: snopes
# gun: snopes, africacheck
# fact check: snopes
# recreation: politifact
# cpc: factscan
# russia: snopes
# alcohol: politifact, snopes, africacheck
# woman: snopes, africacheck
# message machine 2014: politifact
# racism: snopes
# the last line of defense: snopes
# america 's last line of defense: snopes
# your news wire: snopes
# gun control: snopes
# election: snopes, factscan, africacheck
# pensions: politifact
# conspiracy theory: snopes
# fauxtography: snopes
# jacob zuma: africacheck, snopes
# state government spending: politifact
# president trump: snopes
# something for nothing: snopes
# weather: politifact, snopes
# oil spill: politifact
# television: snopes
# pop culture: politifact
# afghanistan: politifact, snopes
# crusader habit: snopes
# radio & tv: snopes
# animals: politifact
# county budget: politifact
# israel: politifact, snopes
# county government: politifact
# human rights: politifact
# new hampshire 2012: politifact
# marriage: politifact, snopes, africacheck
# bernie sander: snopes
# viral video: snopes
# debates: politifact
# sexuality: politifact, snopes
# natural phenomena: snopes
# music: snopes
# development: africacheck
# wealth: politifact, africacheck
# congressional rules: politifact
# population: politifact, africacheck
# infrastructure: politifact, africacheck
# hoax: snopes, africacheck
# movies: snopes
# china: politifact, snopes, africacheck
# florida: politifact, snopes
# welfare: politifact, snopes, africacheck
# world news daily report: snopes
# muslim: snopes
# small business: politifact
# negative campaigning: politifact
# politics: snopes, africacheck
# veterans: politifact, factscan
# retirement: politifact
# nuclear: politifact, snopes
# transparency: politifact
# unions: politifact
# city budget: politifact
# islam: politifact, snopes
# this week - abc news: politifact
# sports: politifact
# bipartisanship: politifact
# facebook: snopes
# science: politifact, snopes, africacheck
# technology: politifact, snopes
# agriculture: politifact, snopes, africacheck
# government: snopes, africacheck
# water: politifact, snopes, africacheck
# financial regulation: politifact
# election 2016: snopes
# diversity: politifact, snopes
# marijuana: politifact, snopes
# gays and lesbians: politifact
# housing: politifact, africacheck
# drugs: politifact
# iraq: politifact, snopes, factscan
# civil rights: politifact
# medicaid: politifact, snopes
# families: politifact
# regulation: politifact, snopes
# trump administration: snopes
# supreme court: politifact, snopes
# debt: politifact, snopes, africacheck
# health: snopes, factscan, africacheck
# animal: snopes
# trade: politifact, factscan, snopes, africacheck
# city government: politifact
# polls and public opinion: politifact
# corporations: politifact
# social security: politifact, snopes
# government efficiency: politifact
# public safety: politifact, snopes
# stimulus: politifact
# religion: politifact, snopes
# not necessarily the news: snopes
# climate change: politifact, snopes, factscan
# ethics: politifact, factscan
# message machine 2010: politifact
# income: politifact
# labor: politifact, snopes
# pundits: politifact
# government regulation: politifact
# voting record: politifact
# deficit: politifact
# poverty: politifact, africacheck
# hillary clinton: snopes
# medicare: politifact, snopes
# homeland security: politifact, snopes
# campaign finance: politifact
# children: politifact
# women: politifact
# message machine 2012: politifact
# barack obama: snopes
# congress: politifact, snopes
# state finances: politifact
# corrections and updates: politifact
# states: politifact
# public health: politifact, snopes
# transportation: politifact
# job accomplishments: politifact
# workers: politifact
# criminal justice: politifact, snopes
# abortion: politifact, snopes
# terrorism: politifact, snopes, africacheck
# military: politifact, snopes
# energy: politifact, factscan, snopes, africacheck
# environment: politifact, factscan, africacheck
# guns: politifact
# legal issues: politifact
# history: politifact, snopes
# foreign policy: politifact
# fake news: politifact, snopes
# crime: politifact, snopes, africacheck
# candidate biography: politifact
# donald trump: snopes
# elections: politifact, africacheck
# state budget: politifact
# federal budget: politifact
# jobs: politifact, factscan
# immigration: politifact, snopes, factscan
# education: politifact, snopes, africacheck
# taxes: politifact, factscan
# economy: politifact, snopes, africacheck
# health care: politifact, snopes
# asp article: snopes

# %%
wb = Workbook()
sheet1 = wb['Sheet']
wb.remove(sheet1)

ws = wb.create_sheet("Keywords")
ws.append(["Keyword", "Occurrences", "Sites"])

#Save keywords to excel
for key in sorted_dict:
    row = [key,sorted_dict[key],organization_dict[key]]
    ws.append(row)
    
#Save Excel File
wb.save("Data/Keywords.xlsx")

# %% [markdown]
# ### Get entities by keyword

# %%
df2 = pd.read_csv('Data/claims_keywords_entities.csv',sep=";")
display(df2.head())
# Out:
#                                                  uri  \
# 0  http://data.gesis.org/claimskg/creative_work/0...
# 1  http://data.gesis.org/claimskg/creative_work/0...
# 2  http://data.gesis.org/claimskg/creative_work/0...
# 3  http://data.gesis.org/claimskg/creative_work/0...
# 4  http://data.gesis.org/claimskg/creative_work/0...
#
#                                             keywords  \
# 0         consumer safety,energy,job accomplishments
# 1                                  military,veterans
# 2                                  military,veterans
# 3                                 big pharma,vaccine
# 4  families,government regulation,health care,pub...
#
#                             entity
# 0  Texas Department of Agriculture
# 1                      John McCain
# 2                     Donald Trump
# 3                    Judy Mikovits
# 4                        pregnancy

# %%
entities_dict = dict.fromkeys(sorted_dict)

for index, row in df2.iterrows():
    keywords = [x.strip() for x in row.keywords.split(',')]
    for keyword in keywords:
        if keyword in entities_dict:
            if entities_dict[keyword] == None:
                entities_dict[keyword] = list()
                entities_dict[keyword].append(row.entity)
            else:
                if row.entity not in entities_dict[keyword]:
                    entities_dict[keyword].append(row.entity)

# %%
wb = Workbook()
sheet1 = wb['Sheet']
wb.remove(sheet1)

ws = wb.create_sheet("Keywords")
ws.append(["Keyword", "Occurrences", "Sites","Entities"])

#Save keywords to excel
for key in sorted_dict:
    row = [key,sorted_dict[key],organization_dict[key]]
    if key != "asp article":
        row.extend(entities_dict[key])
    ws.append(row)
    
#Save Excel File
wb.save("Data/Keywords.xlsx")

# %%
len(entities_dict["donald trump"])
# Out:
# 794

# %% [markdown]
# # Co-occurrence Clustering

# %% [markdown]
# ### Build Matrix

# %%
n = len(keywordList)
matrix = np.zeros((n,n))

for index, row in df.iterrows():
    keywords = [x.strip() for x in row.keywords.split(',')]
    for k1 in keywords:
        try:
            i1 = keywordList.index(k1)
        except ValueError:
            continue
        for k2 in keywords:
            if k1 != k2:
                try:
                    i2 = keywordList.index(k2)
                except ValueError:
                    continue
                matrix[i1][i2] = matrix[i1][i2]+1

# %%
np.savetxt("Data\matrix.csv", matrix, delimiter=",", header=",".join(keywordList),comments="")

# %% [markdown]
# ### Clustering

# %%
def get_clusters(labels,keywordList):
    clusters = dict()
    for wordIndex, clusterIndex in enumerate(labels):
        if clusterIndex > -1:
            if clusterIndex in clusters:
                clusters[clusterIndex] += ", " + keywordList[wordIndex]
            else:
                clusters[clusterIndex] = keywordList[wordIndex]
    return clusters

def get_cluster_distribution(clusters):
    cluster_dist = dict()
    for x in range(0, len(clusters)):
        cluster_dist[x] = dict()
        cluster_dist[x]["TRUE"] = 0
        cluster_dist[x]["FALSE"] = 0
        cluster_dist[x]["MIXTURE"] = 0
        cluster_dist[x]["OTHER"] = 0
        cluster_dist[x]["TOTAL"] = 0

    for index, row in df.iterrows():
        keywords = [x.strip() for x in row.keywords.split(',')]
        rating = row.rating
        for x in range(0, len(clusters)):
            kwl = [y.strip() for y in clusters[x].split(',')]
            for keyword in keywords: 
                if keyword in kwl:
                    cluster_dist[x]["TOTAL"] += 1
                    cluster_dist[x][rating] += 1
                    break
    return cluster_dist

def print_clusters(clusters, cluster_dist):
    for x in range(0, len(clusters)):
        print("Cluster %d (Total: %d, True: %d, False: %d, Mixture: %d, Other: %d)" 
              % (x,cluster_dist[x]["TOTAL"],cluster_dist[x]["TRUE"],cluster_dist[x]["FALSE"]
              ,cluster_dist[x]["MIXTURE"],cluster_dist[x]["OTHER"]))
        print("{ %s } \n" % (clusters[x]))
        
def add_cluster_to_excel(wb,name,clusters,clust_dist):
    ws = wb.create_sheet(name)
    ws.append(["Cluster", "#Claims", "#True","#False","#Mixture","#Other","Keywords"])
    for x in range(0, len(clusters)):
        row = [x+1,clust_dist[x]["TOTAL"],clust_dist[x]["TRUE"],clust_dist[x]["FALSE"]
              ,clust_dist[x]["MIXTURE"],clust_dist[x]["OTHER"]]
        row.extend(clusters[x].split(','))
        ws.append(row)

# %% [markdown]
# ### Cosine similarity

# %%
cs_matrix = cosine_similarity(matrix, matrix)

# %%
#Ward
wb = Workbook()
sheet1 = wb['Sheet']
wb.remove(sheet1)

start = 10
step = 10
stop = 30
stop += step

#Ward with Cosine Similarity Matrix
for n in range(start,stop,step):
    ward = AgglomerativeClustering(n_clusters=n).fit(cs_matrix)
    clusters = get_clusters(ward.labels_,keywordList)
    clust_dist = get_cluster_distribution(clusters)
    add_cluster_to_excel(wb,str(n) + " Clusters",clusters,clust_dist)

#Save Excel File
wb.save("Data/Ward.xlsx")

# %%
#DBSCAN
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2).fit(cs_matrix)
clusters = get_clusters(dbscan.labels_,keywordList)
clust_dist = get_cluster_distribution(clusters)
print_clusters(clusters,clust_dist)
# Out:
# Cluster 0 (Total: 507, True: 57, False: 176, Mixture: 26, Other: 248)
# { tourism, reader suggestion, sona, employment, statistic, woman, election, jacob zuma, development, government, health }
#
# Cluster 1 (Total: 1096, True: 110, False: 672, Mixture: 189, Other: 125)
# { melania trump, satire, trump, russia, racism, the last line of defense, america 's last line of defense, conspiracy theory, president trump, viral video, politics, election 2016, trump administration, hillary clinton }
#
# Cluster 2 (Total: 123, True: 9, False: 88, Mixture: 14, Other: 12)
# { fact check, facebook }
#
# Cluster 3 (Total: 216, True: 45, False: 66, Mixture: 105, Other: 0)
# { recreation, regulation }
#
# Cluster 4 (Total: 904, True: 110, False: 233, Mixture: 556, Other: 5)
# { message machine 2014, new hampshire 2012, debates, this week - abc news, message machine 2010, message machine 2012 }
#
# Cluster 5 (Total: 160, True: 0, False: 151, Mixture: 7, Other: 2)
# { your news wire, world news daily report }
#
# Cluster 6 (Total: 4005, True: 579, False: 928, Mixture: 2388, Other: 110)
# { pensions, state government spending, small business, retirement, unions, financial regulation, corporations, stimulus, income, labor, poverty, state finances, job accomplishments, workers, jobs, education }
#
# Cluster 7 (Total: 895, True: 111, False: 612, Mixture: 55, Other: 117)
# { something for nothing, crusader habit, natural phenomena, music, hoax, movies, animal, not necessarily the news }
#
# Cluster 8 (Total: 756, True: 109, False: 225, Mixture: 397, Other: 25)
# { weather, oil spill, climate change, energy }
#
# Cluster 9 (Total: 604, True: 95, False: 201, Mixture: 301, Other: 7)
# { afghanistan, iraq, terrorism }
#
# Cluster 10 (Total: 181, True: 27, False: 63, Mixture: 88, Other: 3)
# { animals, science }
#
# Cluster 11 (Total: 213, True: 33, False: 55, Mixture: 123, Other: 2)
# { county budget, county government, city budget }
#
# Cluster 12 (Total: 298, True: 24, False: 145, Mixture: 126, Other: 3)
# { human rights, religion }
#
# Cluster 13 (Total: 259, True: 24, False: 63, Mixture: 145, Other: 27)
# { china, trade }
#
# Cluster 14 (Total: 843, True: 108, False: 274, Mixture: 449, Other: 12)
# { florida, technology, pundits, corrections and updates }
#
# Cluster 15 (Total: 1648, True: 259, False: 519, Mixture: 816, Other: 54)
# { negative campaigning, transparency, bipartisanship, ethics, campaign finance, elections }
#
# Cluster 16 (Total: 277, True: 51, False: 63, Mixture: 145, Other: 18)
# { agriculture, housing }
#
# Cluster 17 (Total: 419, True: 39, False: 119, Mixture: 251, Other: 10)
# { medicaid, medicare }
#
# Cluster 18 (Total: 757, True: 100, False: 223, Mixture: 421, Other: 13)
# { polls and public opinion, voting record, congress }
#
# Cluster 19 (Total: 1979, True: 265, False: 490, Mixture: 1183, Other: 41)
# { government efficiency, transportation, taxes }
#
# Cluster 20 (Total: 1045, True: 162, False: 274, Mixture: 599, Other: 10)
# { public safety, criminal justice, guns }
#
# Cluster 21 (Total: 750, True: 103, False: 228, Mixture: 405, Other: 14)
# { public health, abortion }

# %%
#OPTICS
from sklearn.cluster import OPTICS

wb = Workbook()
sheet1 = wb['Sheet']
wb.remove(sheet1)

optics = OPTICS(xi=.05,min_cluster_size=2).fit(cs_matrix)
clusters = get_clusters(optics.labels_,keywordList)
clust_dist = get_cluster_distribution(clusters)
#print_clusters(clusters,clust_dist)
add_cluster_to_excel(wb,"OPTICS",clusters,clust_dist)

wb.save("Data/Optics.xlsx")

# %% [markdown]
# # Occurrence Clustering

# %% [markdown]
# ### Build matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

def dummy_tokenizer(docs):
    return docs

def tokenize_docs():
    docs = list()
    for index, row in df.iterrows():
        tokens = [x.strip() for x in row.keywords.split(',')]
        docs.append(tokens)
    return docs

# %%
#Vectorization
docs = tokenize_docs()
vectorizer = TfidfVectorizer(tokenizer=dummy_tokenizer,
    preprocessor=dummy_tokenizer,min_df=50)
doc_kw = vectorizer.fit_transform(docs)

#Transpose the matrix so that keywords become data points and documents become features
kw_doc = np.transpose(doc_kw)

#Get the vocabulary list
vocab = sorted(vectorizer.vocabulary_.items(), key=lambda kv: kv[1])
vocab = collections.OrderedDict(vocab)
vlist = list(vocab)

# %%
dense = kw_doc.toarray()
ward = AgglomerativeClustering(n_clusters=20).fit(dense)
clusters = get_clusters(ward.labels_,vlist)
clust_dist = get_cluster_distribution(clusters)
print_clusters(clusters,clust_dist)
# Out:
# Cluster 0 (Total: 13619, True: 1790, False: 4926, Mixture: 6073, Other: 830)
# { afghanistan, agriculture, alcohol, america 's last line of defense, animal, animals, barack obama, bernie sander, bipartisanship, campaign finance, children, china, city budget, city government, civil rights, climate change, congress, congressional rules, conspiracy theory, corporations, corrections and updates, county budget, county government, cpc, criminal justice, crusader habit, debates, debt, deficit, development, diversity, drugs, ebola, election, election 2016, employment, ethics, facebook, fact check, families, fauxtography, financial regulation, florida, gays and lesbians, government, government efficiency, government regulation, gun, gun control, health, hillary clinton, hoax, homeland security, housing, human rights, income, infrastructure, iraq, islam, israel, jacob zuma, job accomplishments, labor, legal issues, marijuana, marriage, medicaid, medicare, melania trump, message machine 2010, message machine 2012, message machine 2014, military, movies, music, muslim, natural phenomena, negative campaigning, new hampshire 2012, not necessarily the news, nuclear, oil spill, pensions, politics, polls and public opinion, pop culture, population, poverty, president trump, public health, public safety, pundits, racism, radio & tv, reader suggestion, recreation, regulation, religion, retirement, russia, satire, science, sexuality, small business, social security, something for nothing, sona, space, sports, state finances, state government spending, states, statistic, stimulus, supreme court, technology, television, terrorism, the last line of defense, this week - abc news, tourism, trade, transparency, transportation, trump, trump administration, unions, veterans, viral video, voting record, water, wealth, weather, welfare, woman, women, workers, world news daily report, your news wire }
#
# Cluster 1 (Total: 882, True: 117, False: 246, Mixture: 482, Other: 37)
# { energy, environment }
#
# Cluster 2 (Total: 979, True: 141, False: 237, Mixture: 586, Other: 15)
# { state budget }
#
# Cluster 3 (Total: 1467, True: 180, False: 363, Mixture: 898, Other: 26)
# { taxes }
#
# Cluster 4 (Total: 1037, True: 157, False: 225, Mixture: 634, Other: 21)
# { jobs }
#
# Cluster 5 (Total: 1719, True: 186, False: 539, Mixture: 973, Other: 21)
# { health care }
#
# Cluster 6 (Total: 536, True: 77, False: 147, Mixture: 309, Other: 3)
# { guns }
#
# Cluster 7 (Total: 729, True: 85, False: 213, Mixture: 411, Other: 20)
# { foreign policy }
#
# Cluster 8 (Total: 1086, True: 114, False: 360, Mixture: 561, Other: 51)
# { immigration }
#
# Cluster 9 (Total: 605, True: 100, False: 220, Mixture: 280, Other: 5)
# { history }
#
# Cluster 10 (Total: 906, True: 125, False: 300, Mixture: 469, Other: 12)
# { candidate biography }
#
# Cluster 11 (Total: 854, True: 7, False: 794, Mixture: 44, Other: 9)
# { fake news }
#
# Cluster 12 (Total: 1029, True: 157, False: 237, Mixture: 612, Other: 23)
# { federal budget }
#
# Cluster 13 (Total: 1216, True: 183, False: 257, Mixture: 717, Other: 59)
# { education }
#
# Cluster 14 (Total: 1714, True: 297, False: 372, Mixture: 975, Other: 70)
# { economy }
#
# Cluster 15 (Total: 3311, True: 456, False: 1897, Mixture: 326, Other: 632)
# { asp article }
#
# Cluster 16 (Total: 890, True: 118, False: 266, Mixture: 467, Other: 39)
# { crime }
#
# Cluster 17 (Total: 924, True: 135, False: 465, Mixture: 219, Other: 105)
# { donald trump }
#
# Cluster 18 (Total: 409, True: 64, False: 129, Mixture: 204, Other: 12)
# { abortion }
#
# Cluster 19 (Total: 979, True: 160, False: 327, Mixture: 456, Other: 36)
# { elections }

# %%
dense = kw_doc.toarray()
ward = AgglomerativeClustering(n_clusters=5).fit(dense)
clusters = get_clusters(ward.labels_,vlist)
clust_dist = get_cluster_distribution(clusters)
print_clusters(clusters,clust_dist)
# Out:
# Cluster 0 (Total: 18543, True: 2466, False: 6831, Mixture: 8221, Other: 1025)
# { abortion, afghanistan, agriculture, alcohol, america 's last line of defense, animal, animals, barack obama, bernie sander, bipartisanship, campaign finance, candidate biography, children, china, city budget, city government, civil rights, climate change, congress, congressional rules, conspiracy theory, corporations, corrections and updates, county budget, county government, cpc, crime, criminal justice, crusader habit, debates, debt, deficit, development, diversity, donald trump, drugs, ebola, education, election, election 2016, elections, employment, energy, environment, ethics, facebook, fact check, fake news, families, fauxtography, federal budget, financial regulation, florida, foreign policy, gays and lesbians, government, government efficiency, government regulation, gun, gun control, guns, health, hillary clinton, history, hoax, homeland security, housing, human rights, immigration, income, infrastructure, iraq, islam, israel, jacob zuma, job accomplishments, labor, legal issues, marijuana, marriage, medicaid, medicare, melania trump, message machine 2010, message machine 2012, message machine 2014, military, movies, music, muslim, natural phenomena, negative campaigning, new hampshire 2012, not necessarily the news, nuclear, oil spill, pensions, politics, polls and public opinion, pop culture, population, poverty, president trump, public health, public safety, pundits, racism, radio & tv, reader suggestion, recreation, regulation, religion, retirement, russia, satire, science, sexuality, small business, social security, something for nothing, sona, space, sports, state budget, state finances, state government spending, states, statistic, stimulus, supreme court, technology, television, terrorism, the last line of defense, this week - abc news, tourism, trade, transparency, transportation, trump, trump administration, unions, veterans, viral video, voting record, water, wealth, weather, welfare, woman, women, workers, world news daily report, your news wire }
#
# Cluster 1 (Total: 2208, True: 360, False: 487, Mixture: 1270, Other: 91)
# { economy, jobs }
#
# Cluster 2 (Total: 1719, True: 186, False: 539, Mixture: 973, Other: 21)
# { health care }
#
# Cluster 3 (Total: 3311, True: 456, False: 1897, Mixture: 326, Other: 632)
# { asp article }
#
# Cluster 4 (Total: 1467, True: 180, False: 363, Mixture: 898, Other: 26)
# { taxes }

# %%
#Dendrogram Test
import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram

def llf(id):
        return 'C%d - %s' % (ward.labels_[id]+1, keywordList[id])

def plot_dendrogram(model, **kwargs):
    # Children of hierarchical clustering
    children = model.children_
    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])
    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)
    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)
    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs, leaf_rotation=90, leaf_font_size=12)
    
ward = AgglomerativeClustering(n_clusters=30).fit(cs_matrix)
# clusters = get_clusters(ward.labels_,keywordList)
# clust_dist = get_cluster_distribution(clusters)
# add_cluster_to_excel(wb,str(n) + " Clusters",clusters,clust_dist)

# %%
fig = plt.figure(figsize=(50,50))
plt.title('Hierarchical Clustering Dendrogram')
#plot_dendrogram(ward, labels=keywordList)
plot_dendrogram(ward, leaf_label_func=llf)
plt.show()

fig.savefig("Ward 30 Clusters.pdf", bbox_inches='tight')
